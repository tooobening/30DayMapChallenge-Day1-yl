# %%
import requests
from bs4 import BeautifulSoup
import json
import re
from typing import Dict, List
import pandas as pd
from pathlib import Path
import os

# %%
# Base configuration
BASE_URL = "https://wisconsinsupperclubs.com"
REGIONS = {
    "southeast": "/southeast-region/",
    "southwest": "/southwest-region/", 
    "northeast": "/northeast-region/",
    "north-central": "/north-central-region/",
    "northwest": "/northwest-region/"
}

# %%
def clean_address(text: str) -> str:
    """Clean address text by removing extra whitespace and HTML tags"""
    text = re.sub(r'\s+', ' ', text).strip()
    text = re.sub(r'<.*?>', '', text)
    return text

def parse_club(div, region: str) -> Dict:
    """Parse information for a single supper club"""
    club_data = {
        'region': region  # Add region information
    }
    
    # Get club name
    title = div.find('h2', class_='fl-post-grid-title')
    if title:
        club_data['name'] = title.text.strip()
        
        # Get club detail page URL
        link = title.find('a')
        if link:
            club_data['url'] = link.get('href', '')
    
    # Get address and contact information
    content = div.find('div', class_='fl-post-grid-content')
    if content and content.find('p'):
        address_text = content.find('p').get_text().split('\n')
        address_text = [line.strip() for line in address_text if line.strip()]
        
        # Remove website link line but save website URL
        if len(address_text) > 1:
            website = content.find('a')
            if website:
                club_data['website'] = website.get('href', '')
            address_text = address_text[1:]
        
        # Parse address components
        if len(address_text) >= 1:
            club_data['address'] = address_text[0]
        
        if len(address_text) >= 2:
            city_state_zip = address_text[1].split()
            if len(city_state_zip) >= 2:
                club_data['city'] = ' '.join(city_state_zip[:-2]) 
                club_data['state'] = city_state_zip[-2]
                club_data['zip_code'] = city_state_zip[-1]
        
        if len(address_text) >= 3:
            club_data['phone'] = address_text[2]
    
    return club_data

def scrape_region(region: str, url: str) -> List[Dict]:
    """Scrape all supper clubs from a specific region"""
    print(f"Scraping {region} region...")
    clubs = []
    
    try:
        # Send HTTP request
        response = requests.get(url)
        response.raise_for_status()
        
        # Parse HTML
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Find all supper club blocks
        club_divs = soup.find_all('div', class_='fl-post-grid-post')
        
        # Parse each club's information
        for div in club_divs:
            club_data = parse_club(div, region)
            if club_data:
                clubs.append(club_data)
                print(f"Parsed: {club_data['name']}")
        
        print(f"Found {len(clubs)} supper clubs in {region} region")
        return clubs
        
    except Exception as e:
        print(f"Error scraping {region}: {str(e)}")
        return []

def scrape_all_regions_to_json() -> List[Dict]:
    """Scrape supper clubs from all regions and return as a single list"""
    all_clubs = []
    
    for region, path in REGIONS.items():
        url = BASE_URL + path
        clubs = scrape_region(region, url)
        all_clubs.extend(clubs)
        
        # Add delay between requests
        time.sleep(2)
    
    # Save all clubs as a single list
    with open('data/wi_supper_clubs_2023.json', 'w', encoding='utf-8') as f:
        json.dump(all_clubs, f, ensure_ascii=False, indent=2)
    
    return all_clubs

# %%
print("Starting to scrape Wisconsin supper clubs information...")
clubs = scrape_all_regions_to_json()

# Print statistics
print(f"\nTotal clubs found: {len(clubs)}")

# Print count by region
region_counts = {}
for club in clubs:
    region = club['region']
    region_counts[region] = region_counts.get(region, 0) + 1

print("\n=== Clubs by Region ===")
for region, count in region_counts.items():
    print(f"{region}: {count} clubs")

print("\nData saved to supper_clubs.json")
# Out:
# Starting to scrape Wisconsin supper clubs information...
# Scraping southeast region...
# Parsed: 5 O’Clock Club
# Parsed: Alpine Retreat
# Parsed: Bass Bay Brewhouse
# Parsed: Bayside Supper Club
# Parsed: Blue Heron Supper Club
# Parsed: Brittain House Supper Club
# Parsed: Butler Inn of Pewaukee
# Parsed: Cantafio’s Buckhorn Steakhouse
# Parsed: Clifford’s Supper Club
# Parsed: Colony House **
# Parsed: Copper Dock, The *†
# Parsed: Corner House Supper Club
# Parsed: Diamond Jim’s Steakhouse *†
# Parsed: Duck Inn, The *†
# Parsed: Edgewater Supper Club **
# Parsed: Feil’s Supper Club
# Parsed: Fitzgerald’s Genoa Junction **
# Parsed: Five O’Clock Steakhouse **
# Parsed: Great Outdoors Supper Club †
# Parsed: HobNob *†
# Parsed: House of Gerhard
# Parsed: Iron Ridge Inn
# Parsed: Jack Pandl’s Whitefish Bay Inn
# Parsed: Jackson Grill, The
# Parsed: Jail House, The
# Parsed: Joey Gerard’s Supper Club
# Parsed: Johnny Manhattan’s
# Parsed: Juice’s Ghost Town
# Parsed: Kurt’s Steakhouse
# Parsed: Little Red Inn
# Parsed: Mars Resort
# Parsed: Michael’s on the Lake
# Parsed: Milwaukee Steakhouse
# Parsed: Moonlight Tavern Supper Club
# Parsed: Nite Cap Inn
# Parsed: North Shore Chophouse
# Parsed: Olde Cedar Inn, The
# Parsed: Pitch’s
# Parsed: Plier’s Full Circle
# Parsed: Range Line Inn
# Parsed: Red Circle Inn
# Parsed: Relish Supper Club
# Parsed: Sandra’s on the Park
# Parsed: Schaumburg Dinner Club
# Parsed: Shores of Fox Lake, The
# Parsed: Silver Lake Country Inn
# Parsed: Stagecoach Inn **
# Parsed: Steakout, The †
# Parsed: Timmer’s Resort
# Parsed: Village Supper Club
# Parsed: Village Supper Club
# Parsed: Voelker’s Steak House
# Parsed: Wayside Inn, The
# Parsed: Wilmot Stage Stop
# Parsed: Wisco Supper Club, The
# Found 55 supper clubs in southeast region
# Scraping southwest region...
# Parsed: 3 Mile House *†
# Parsed: 615 Club, The **
# Parsed: Arthur’s Supper Club **
# Parsed: Badger Crossing
# Parsed: Benedetti’s Club 51 *†
# Parsed: Buckhorn Supper Club *†
# Parsed: Butterfly Club, The *†
# Parsed: Chop’s Kall Inn *†
# Parsed: Cimaroli’s Supper Club *†
# Parsed: Club 60
# Parsed: Club Oasis **
# Parsed: Cottonwood, The
# Parsed: Country Heights Supper Club *†
# Parsed: Crossroads Supper Club
# Parsed: Del Bar, The **
# Parsed: Delaney’s **
# Parsed: Digger’s Sting
# Parsed: Dorf Haus Supper Club *†
# Parsed: Driftless Social
# Parsed: Drugan’s Castle Mound
# Parsed: Fish Tales
# Parsed: Fitz’s on the Lake
# Parsed: Fredrick’s Supper Club †
# Parsed: Freighthouse Restaurant
# Parsed: Green Acres Supper Club **
# Parsed: Green Lantern Restaurant
# Parsed: Hi Point Steakhouse †
# Parsed: Hideaway Acres
# Parsed: Hilltop, The †
# Parsed: House of Embers
# Parsed: Ishnala *†
# Parsed: Jones’ Black Angus *†
# Parsed: Kickapoo Creekside
# Parsed: Lake House Inn
# Parsed: Louisburg Junction Supper Club
# Parsed: Maple Tree Supper Club
# Parsed: Mariner’s
# Parsed: Old Towne Inn **
# Parsed: Owl’s Nest
# Parsed: Red’s Supper Club
# Parsed: Rex’s Innkeeper
# Parsed: Ridge, The
# Parsed: Rocky’s Supper Club *†
# Parsed: Suzy’s Steak & Seafood
# Parsed: Toby’s Supper Club
# Parsed: Tornado Club Steak House *†
# Parsed: Turn Key Supper Club
# Parsed: Village Bar Supper Club, The **
# Parsed: Village Inn
# Parsed: Westview Inn
# Parsed: Woodbine Inn
# Parsed: Zeman’s Old Highway House
# Found 52 supper clubs in southwest region
# Scraping northeast region...
# Parsed: Alexander’s
# Parsed: Altona Supper Club
# Parsed: Anderson’s Supper Club
# Parsed: Ballering, The
# Parsed: Bavarian Inn
# Parsed: Billy’s on Main
# Parsed: Black Otter Supper Club
# Parsed: Blanck’s Supper Club †
# Parsed: Boarding House **
# Parsed: Bob & Laura’s Supper Club
# Parsed: Brown’s Corner
# Parsed: Butte Des Morts Supper Club
# Parsed: Cattails Supper Club
# Parsed: Cedar Lodge
# Parsed: Century Elm Supper Club
# Parsed: Chissy’s Pub & Grill
# Parsed: Club Chalet **
# Parsed: Colonial House Supper Club
# Parsed: Dan and Tim’s Riverside
# Parsed: Dick and Joan’s Supper Club
# Parsed: Donny’s Glidden Lodge †
# Parsed: Embers 1871
# Parsed: English Inn, The
# Parsed: Five Pillars Supper Club
# Parsed: Geno’s Steakhouse †
# Parsed: George’s Steakhouse
# Parsed: Gib’s on the Lake **
# Parsed: Gobbler’s Knob
# Parsed: Granary Supper Club, The
# Parsed: Haase’s Supper Club
# Parsed: Harbor Fish Market & Grille
# Parsed: Harborside
# Parsed: Hillcrest Lodge Supper Club
# Parsed: Hotel Seymour Supper Club
# Parsed: Jim and Linda’s Lakeview
# Parsed: Jimmies White House Inn
# Parsed: Koehring’s Grand Central House
# Parsed: Krabbe’s Supper Club
# Parsed: Kropp’s Supper Club *†
# Parsed: Long Drive Supper Club
# Parsed: Lox Club *†
# Parsed: Maiden Lake Supper Club *†
# Parsed: Majerle’s Black River Grill †
# Parsed: Mark’s East Side
# Parsed: Marq Supper Club, The
# Parsed: Marty’s Place Supper Club
# Parsed: Michiels of Menasha
# Parsed: Mill Supper Club, The *†
# Parsed: Millhome Supper Club
# Parsed: Moxie’s Supper Club
# Parsed: Nightingale Supper Club **
# Parsed: Nimrod Inn Supper Club
# Parsed: Off the Wolf Supper Club
# Parsed: Out-O-Town Supper Club
# Parsed: PJ Campbell’s at the Depot
# Parsed: Prime Steer Supper Club
# Parsed: Red Cabin at Green Acres
# Parsed: Red Ox Seafood & Steak
# Parsed: Redwood Inn
# Parsed: Rene’s Dining Room
# Parsed: Richards of Dunbar Supper Club
# Parsed: River’s Bend
# Parsed: River’s Edge, The **
# Parsed: Rock Falls Supper Club
# Parsed: Roepke’s Supper Club *†
# Parsed: Romy’s Nitingale
# Parsed: Roxy Supper Club, The
# Parsed: Rupp’s Downtown
# Parsed: Rupp’s Supper Club
# Parsed: Schmitz Brothers 2 Supper Club
# Parsed: Schwarz’s Supper Club *†
# Parsed: Sebastian’s Steak House
# Parsed: Sister Bay Bowl
# Parsed: T&T Steakhouse
# Parsed: Theo’s 24
# Parsed: Twin Bridge Supper Club
# Parsed: Union Hotel
# Parsed: Van Abel’s of Hollandtown
# Parsed: Weatherwood Supper Club
# Parsed: Wendt’s on the Lake
# Parsed: Whitetail Inn
# Parsed: Wildflower Supper Club
# Found 82 supper clubs in northeast region
# Scraping north-central region...
# Parsed: Aberdeen Restaurant & Bar
# Parsed: Amy’s Roadhouse
# Parsed: Antlers Supper Club *†
# Parsed: Asana Suka
# Parsed: Ash’s
# Parsed: Bear Trap Inn, The †
# Parsed: Belvedere Supper Club
# Parsed: Besse’s on Clear Lake
# Parsed: Bootleggers Lodge
# Parsed: Branding Iron Supper Club **
# Parsed: Buck-A-Neer Supper Club *†
# Parsed: Chanticleer Inn
# Parsed: Chef Rene’s at Eagle River
# Parsed: Classic’s Restaurant & Lounge
# Parsed: Clearview Supper Club
# Parsed: Club 22
# Parsed: Club 23
# Parsed: Cove Supper Club, The
# Parsed: Crystal’s Wood Lake Supper Club
# Parsed: Dixon’s Torchlite
# Parsed: Dockers on the Corner
# Parsed: Eagle Waters Resort
# Parsed: Eddie B’s White Spruce
# Parsed: El Capitan Supper Club
# Parsed: Fireside Supper Club
# Parsed: Four Seasons Supper Club **
# Parsed: Guide’s Inn, The
# Parsed: Hidden Valley Supper Club
# Parsed: JJ’s on Main
# Parsed: Jung’s Nutshell Supper Club
# Parsed: Kassidy’s Studio Lounge
# Parsed: Kathy & Cal’s Club 64
# Parsed: Lake Aire Supper Club
# Parsed: Lanny’s Fireside Supper Club
# Parsed: Lawson’s Triple O Supper Club
# Parsed: Marty’s Place North
# Parsed: Mathew’s Supper Club
# Parsed: McGregor’s Blink Bonnie
# Parsed: Mecan River Lodge
# Parsed: Meyer’s Clint Mar Supper Club
# Parsed: Michele’s Supper Club
# Parsed: MJ’s Supper Club
# Parsed: Moose Inn, The
# Parsed: Northfork Fin & Filet
# Parsed: Norton’s of Green Lake
# Parsed: Norwood Pines Supper Club *†
# Parsed: Palms Supper Club
# Parsed: Pine Tree Supper Club
# Parsed: Pine Tree Supper Club **
# Parsed: Pinewood Supper Club *†
# Parsed: Pub ‘N’ Prime
# Parsed: Richard’s Restaurant & Bar
# Parsed: Savory Steakhouse
# Parsed: Silver Birch Supper Club **
# Parsed: Silvercryst Supper Club *†
# Parsed: Simpson’s in Waupaca
# Parsed: Sky Club *†
# Parsed: Smokey’s
# Parsed: Swartzendruber’s Supper Club
# Parsed: Three Coins at Holiday Acres
# Parsed: Twilight Supper Club
# Parsed: Two Lakes **
# Parsed: Wally’s South 17 Supper Club
# Parsed: Washington Inn Supper Club *†
# Parsed: Waters Supper Club, The
# Parsed: White Stag Inn *†
# Parsed: Whitetail Inn
# Parsed: William’s Pine Gables
# Parsed: Willow Haven Bar & Grill
# Parsed: Wolff’s River Inn †
# Found 70 supper clubs in north-central region
# Scraping northwest region...
# Parsed: 5 O’Clock Club
# Parsed: Beedles Bar & Restaurant
# Parsed: Buckhorn Bar, The
# Parsed: Buskey Bay Resort
# Parsed: Castle Hill Supper Club
# Parsed: Cousin’s Hide-A-Way
# Parsed: Dalles House, The
# Parsed: Ding-A-Ling Supper Club
# Parsed: Dreamland Supper Club
# Parsed: Eddie’s
# Parsed: Evergreens Supper Club
# Parsed: Fannie’s Supper Club & Motel
# Parsed: Hammond Steak House
# Parsed: High View Inn
# Parsed: Hillside Fish House
# Parsed: Hilltop Retreat
# Parsed: Houligans Steak & Seafood Pub
# Parsed: Indianhead Supper Club
# Parsed: Inwood Supper Club
# Parsed: Jake’s Supper Club
# Parsed: John & Heidi’s Happy Daze
# Parsed: JS Supper Club
# Parsed: Kimball Inn
# Parsed: Kincaid’s Country Inn
# Parsed: Kutzee’s Supper Club
# Parsed: Laurel Supper Club, The
# Parsed: Lehman’s Supper Club
# Parsed: Monkey’s Roost
# Parsed: Northwoods Supper Club
# Parsed: Old Abe’s Supper Club
# Parsed: P&E Steakhouse
# Parsed: Pine Ridge
# Parsed: Ranch Supper Club, The *†
# Parsed: Rolling Oaks Supper Club
# Parsed: Shady Grove
# Parsed: Steakhouse & Lodge, The
# Parsed: Sullivan’s Supper Club
# Parsed: Sunset Bay Supper Club
# Parsed: Tally Ho Supper Club
# Parsed: Trailways Inn Supper Club
# Parsed: Turtle Club
# Parsed: Wason’s Supper Club
# Parsed: West Wind Supper Club
# Parsed: Wildcat Supper Club
# Parsed: Wissota High Shores Supper Club
# Found 45 supper clubs in northwest region
#
# Total clubs found: 304
#
# === Clubs by Region ===
# southeast: 55 clubs
# southwest: 52 clubs
# northeast: 82 clubs
# north-central: 70 clubs
# northwest: 45 clubs
#
# Data saved to supper_clubs.json

# %%
type(clubs)
# Out:
# list

# %%
len(clubs)
# Out:
# 304

# %%
print(json.dumps(clubs, ensure_ascii=False, indent=2))
# Out:
# [
#   {
#     "region": "southeast",
#     "name": "5 O’Clock Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/5-oclock-club-2/",
#     "website": "https://the5oclockclubpewaukee.com",
#     "address": "N28 W26658 Peterson Drive",
#     "city": "Pewaukee",
#     "state": "WI",
#     "zip_code": "53072",
#     "phone": "262-691-9960"
#   },
#   {
#     "region": "southeast",
#     "name": "Alpine Retreat",
#     "url": "https://wisconsinsupperclubs.com/supper-club/alpine-retreat/",
#     "website": "https://www.alpineretreat.net/",
#     "address": "1380 Friess Lake Road",
#     "city": "Hubertus,",
#     "state": "WI",
#     "zip_code": "53033",
#     "phone": "262-628-3995"
#   },
#   {
#     "region": "southeast",
#     "name": "Bass Bay Brewhouse",
#     "url": "https://wisconsinsupperclubs.com/supper-club/bass-bay-brewhouse/",
#     "website": "https://www.bassbaybrewhouse.com",
#     "address": "S79 W15851 Aud Mar Drive",
#     "city": "Muskego,",
#     "state": "WI",
#     "zip_code": "53150",
#     "phone": "414-377-9449"
#   },
#   {
#     "region": "southeast",
#     "name": "Bayside Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/bayside-supper-club/",
#     "website": "https://www.restaurantji.com/wi/beaver-dam/bayside-supper-club-/",
#     "address": "W9231 County Road G",
#     "city": "Beaver Dam,",
#     "state": "WI",
#     "zip_code": "53916",
#     "phone": "920-887-0505"
#   },
#   {
#     "region": "southeast",
#     "name": "Blue Heron Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/blue-heron-supper-club/",
#     "website": "https://www.facebook.com/theblueheronsupperclub/",
#     "address": "W229 S8300 Hwy 164",
#     "city": "Big Bend,",
#     "state": "WI",
#     "zip_code": "53103",
#     "phone": "262-662-9985"
#   },
#   {
#     "region": "southeast",
#     "name": "Brittain House Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/brittain-house-supper-club/",
#     "website": "https://www.facebook.com/Brittain-House-Supper-Club-1701362813414555/",
#     "address": "735 South Watertown Street",
#     "city": "Waupun,",
#     "state": "WI",
#     "zip_code": "53963",
#     "phone": "920-345-1800"
#   },
#   {
#     "region": "southeast",
#     "name": "Butler Inn of Pewaukee",
#     "url": "https://wisconsinsupperclubs.com/supper-club/butler-inn-of-pewaukee/",
#     "website": "http://butlerinnofpewaukee.com",
#     "address": "742 Glacier Road",
#     "city": "Pewaukee,",
#     "state": "WI",
#     "zip_code": "53072",
#     "phone": "262-691-0840"
#   },
#   {
#     "region": "southeast",
#     "name": "Cantafio’s Buckhorn Steakhouse",
#     "url": "https://wisconsinsupperclubs.com/supper-club/cantafios-buckhorn-steakhouse/",
#     "website": "https://www.cantafiosbuckhornsteakhouse.com",
#     "address": "N8802 County Road A",
#     "city": "Beaver Dam,",
#     "state": "WI",
#     "zip_code": "53916",
#     "phone": "920-885-0505"
#   },
#   {
#     "region": "southeast",
#     "name": "Clifford’s Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/cliffords-supper-club/",
#     "website": "http://www.cliffordsfinefood.com",
#     "address": "10418 West Forest Home Avenue",
#     "city": "Hales Corners,",
#     "state": "WI",
#     "zip_code": "53130",
#     "phone": "414-425-6226"
#   },
#   {
#     "region": "southeast",
#     "name": "Colony House **",
#     "url": "https://wisconsinsupperclubs.com/supper-club/colony-house/",
#     "website": "https://www.facebook.com/Colony-House-Restaurant-116258141736504/",
#     "address": "25811 119th Street",
#     "city": "Trevor,",
#     "state": "WI",
#     "zip_code": "53179",
#     "phone": "262-862-2076"
#   },
#   {
#     "region": "southeast",
#     "name": "Copper Dock, The *†",
#     "url": "https://wisconsinsupperclubs.com/supper-club/the-copper-dock-%e2%80%a0/",
#     "website": "http://www.thecopperdock.com/",
#     "address": "1474 East Friess Lake Drive",
#     "city": "Hubertus,",
#     "state": "WI",
#     "zip_code": "53033",
#     "phone": "262-628-3718"
#   },
#   {
#     "region": "southeast",
#     "name": "Corner House Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/corner-house-supper-club/",
#     "website": "https://www.chsupperclub.com",
#     "address": "207 Gas Light Circle",
#     "city": "Racine,",
#     "state": "WI",
#     "zip_code": "53403",
#     "phone": "262-637-1295"
#   },
#   {
#     "region": "southeast",
#     "name": "Diamond Jim’s Steakhouse *†",
#     "url": "https://wisconsinsupperclubs.com/supper-club/diamond-jims-steakhouse-%e2%80%a0/",
#     "website": "http://diamondjimssteakhouse.com",
#     "address": "11811 West Janesville Road",
#     "city": "Hales Corners,",
#     "state": "WI",
#     "zip_code": "53130",
#     "phone": "414-425-7777"
#   },
#   {
#     "region": "southeast",
#     "name": "Duck Inn, The *†",
#     "url": "https://wisconsinsupperclubs.com/supper-club/the-duck-inn-%e2%80%a0/",
#     "website": "http://www.duckinndelavan.com/",
#     "address": "N6214 Hwy 89",
#     "city": "Delavan,",
#     "state": "WI",
#     "zip_code": "53115",
#     "phone": "608-883-6988"
#   },
#   {
#     "region": "southeast",
#     "name": "Edgewater Supper Club **",
#     "url": "https://wisconsinsupperclubs.com/supper-club/edgewater-supper-club/",
#     "website": "http://theedgewatersupperclub.com/",
#     "address": "N3522 County Road K",
#     "city": "Jefferson,",
#     "state": "WI",
#     "zip_code": "53549",
#     "phone": "920-674-9942"
#   },
#   {
#     "region": "southeast",
#     "name": "Feil’s Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/feils-supper-club/",
#     "website": "https://www.feilssupperclub.com",
#     "address": "N8743 Hwy 73",
#     "city": "Randolph,",
#     "state": "WI",
#     "zip_code": "53956",
#     "phone": "920-326-5544"
#   },
#   {
#     "region": "southeast",
#     "name": "Fitzgerald’s Genoa Junction **",
#     "url": "https://wisconsinsupperclubs.com/supper-club/fitzgeralds-genoa-junction/",
#     "website": "http://fitzgeraldsfishboil.com/",
#     "address": "727 Main Street (Hwy B)",
#     "city": "Genoa City,",
#     "state": "WI",
#     "zip_code": "53128",
#     "phone": "262-279-5200"
#   },
#   {
#     "region": "southeast",
#     "name": "Five O’Clock Steakhouse **",
#     "url": "https://wisconsinsupperclubs.com/supper-club/five-oclock-steakhouse/",
#     "website": "https://www.facebook.com/FiveOClockSteak/",
#     "address": "2416 West State Street",
#     "city": "Milwaukee,",
#     "state": "WI",
#     "zip_code": "53233",
#     "phone": "414-342-3553"
#   },
#   {
#     "region": "southeast",
#     "name": "Great Outdoors Supper Club †",
#     "url": "https://wisconsinsupperclubs.com/supper-club/great-outdoors-supper-club-%e2%80%a0/",
#     "website": "https://www.greatoutdoorssupperclub.com/",
#     "address": "8906 Forest View Road",
#     "city": "Kewaskum,",
#     "state": "WI",
#     "zip_code": "53040",
#     "phone": "262-334-7977"
#   },
#   {
#     "region": "southeast",
#     "name": "HobNob *†",
#     "url": "https://wisconsinsupperclubs.com/supper-club/hobnob-%e2%80%a0/",
#     "website": "https://thehobnob.com/",
#     "address": "277 Sheridan Rd",
#     "city": "Racine,",
#     "state": "WI",
#     "zip_code": "53403",
#     "phone": "262-552-8008"
#   },
#   {
#     "region": "southeast",
#     "name": "House of Gerhard",
#     "url": "https://wisconsinsupperclubs.com/supper-club/house-of-gerhard/",
#     "website": "http://www.houseofgerhard.com",
#     "address": "3927 75th St",
#     "city": "Kenosha,",
#     "state": "WI",
#     "zip_code": "53142",
#     "phone": "262-694-5212"
#   },
#   {
#     "region": "southeast",
#     "name": "Iron Ridge Inn",
#     "url": "https://wisconsinsupperclubs.com/supper-club/iron-ridge-inn/",
#     "website": "http://www.ironridgeinn.com",
#     "address": "131 South Main Street",
#     "city": "Iron Ridge,",
#     "state": "WI",
#     "zip_code": "53035",
#     "phone": "920-387-3348"
#   },
#   {
#     "region": "southeast",
#     "name": "Jack Pandl’s Whitefish Bay Inn",
#     "url": "https://wisconsinsupperclubs.com/supper-club/jack-pandls-whitefish-bay-inn/",
#     "website": "https://www.jackpandls.com",
#     "address": "1319 East Henry Clay Street",
#     "city": "Whitefish Bay,",
#     "state": "WI",
#     "zip_code": "53217",
#     "phone": "414-964-3800"
#   },
#   {
#     "region": "southeast",
#     "name": "Jackson Grill, The",
#     "url": "https://wisconsinsupperclubs.com/supper-club/the-jackson-grill/",
#     "website": "https://www.facebook.com/people/The-Jackson-Grill/100092849504892/?mibextid=ZbWKwL",
#     "address": "3736 West Mitchell Street",
#     "city": "Milwaukee,",
#     "state": "WI",
#     "zip_code": "53215",
#     "phone": "414-212-8626"
#   },
#   {
#     "region": "southeast",
#     "name": "Jail House, The",
#     "url": "https://wisconsinsupperclubs.com/supper-club/the-jail-house/",
#     "website": "https://www.jailhousewi.com",
#     "address": "897 Pleasant Valley Road",
#     "city": "West Bend,",
#     "state": "WI",
#     "zip_code": "53095",
#     "phone": "262-675-9302"
#   },
#   {
#     "region": "southeast",
#     "name": "Joey Gerard’s Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/joey-gerards-supper-club/",
#     "website": "https://www.bartolottas.com/joey-gerards",
#     "address": "5601 Broad Street",
#     "city": "Greendale,",
#     "state": "WI",
#     "zip_code": "53129",
#     "phone": "414-858-1900"
#   },
#   {
#     "region": "southeast",
#     "name": "Johnny Manhattan’s",
#     "url": "https://wisconsinsupperclubs.com/supper-club/johnny-manhattans/",
#     "website": "http://www.johnnymanhattans.com",
#     "address": "3718 Hubertus Road",
#     "city": "Hubertus,",
#     "state": "WI",
#     "zip_code": "53033",
#     "phone": "262-628-7700"
#   },
#   {
#     "region": "southeast",
#     "name": "Juice’s Ghost Town",
#     "url": "https://wisconsinsupperclubs.com/supper-club/juices-ghost-town/",
#     "website": "https://juicesghostown.com",
#     "address": "990 Ulao Road",
#     "city": "Grafton,",
#     "state": "WI",
#     "zip_code": "53024",
#     "phone": "262-376-9003"
#   },
#   {
#     "region": "southeast",
#     "name": "Kurt’s Steakhouse",
#     "url": "https://wisconsinsupperclubs.com/supper-club/kurts-steakhouse/",
#     "website": "https://www.kurtssteakhouse.com/",
#     "address": "22 West Main Street",
#     "city": "Delafield,",
#     "state": "WI",
#     "zip_code": "53018",
#     "phone": "262-646-3333"
#   },
#   {
#     "region": "southeast",
#     "name": "Little Red Inn",
#     "url": "https://wisconsinsupperclubs.com/supper-club/little-red-inn/",
#     "website": "https://www.littleredinn.com",
#     "address": "4900 WI 175",
#     "city": "Hartford,",
#     "state": "WI",
#     "zip_code": "53027",
#     "phone": "262-644-8181"
#   },
#   {
#     "region": "southeast",
#     "name": "Mars Resort",
#     "url": "https://wisconsinsupperclubs.com/supper-club/mars-resort/",
#     "website": "https://www.mars-resort.com",
#     "address": "W4098 South Shore Drive",
#     "city": "Lake Geneva,",
#     "state": "WI",
#     "zip_code": "53147",
#     "phone": "262-245-5689"
#   },
#   {
#     "region": "southeast",
#     "name": "Michael’s on the Lake",
#     "url": "https://wisconsinsupperclubs.com/supper-club/michaels-on-the-lake/",
#     "website": "https://michaelsonthelakewi.com",
#     "address": "3101 Eagle Road",
#     "city": "Kansasville,",
#     "state": "WI",
#     "zip_code": "53139",
#     "phone": "262-878-3313"
#   },
#   {
#     "region": "southeast",
#     "name": "Milwaukee Steakhouse",
#     "url": "https://wisconsinsupperclubs.com/supper-club/milwaukee-steakhouse/",
#     "website": "http://themilwaukeesteakhouse.com",
#     "address": "6024 West Bluemound Road",
#     "city": "Milwaukee,",
#     "state": "WI",
#     "zip_code": "53213",
#     "phone": "414-312-7891"
#   },
#   {
#     "region": "southeast",
#     "name": "Moonlight Tavern Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/moonlight-tavern-supper-club/",
#     "website": "https://www.northshorechophouse.com",
#     "address": "101 East Main Street",
#     "city": "Port Washington,",
#     "state": "WI",
#     "zip_code": "53074",
#     "phone": "262-235-1981"
#   },
#   {
#     "region": "southeast",
#     "name": "Nite Cap Inn",
#     "url": "https://wisconsinsupperclubs.com/supper-club/nite-cap-inn/",
#     "website": "https://www.restaurantji.com/wi/palmyra/nite-cap-inn-/",
#     "address": "227 South 3rd Street",
#     "city": "Palmyra,",
#     "state": "WI",
#     "zip_code": "53156",
#     "phone": "262-495-2659"
#   },
#   {
#     "region": "southeast",
#     "name": "North Shore Chophouse",
#     "url": "https://wisconsinsupperclubs.com/supper-club/north-shore-chophouse/",
#     "website": "https://www.northshorechophouse.com",
#     "address": "1835 North Shore Road",
#     "city": "Fort Atkinson,",
#     "state": "WI",
#     "zip_code": "53538",
#     "phone": "920-563-2083"
#   },
#   {
#     "region": "southeast",
#     "name": "Olde Cedar Inn, The",
#     "url": "https://wisconsinsupperclubs.com/supper-club/the-olde-cedar-inn/",
#     "website": "https://oldecedarinn.com",
#     "address": "5802 State Hwy 144",
#     "city": "West Bend",
#     "state": "WI",
#     "zip_code": "53095",
#     "phone": "262-629-4400"
#   },
#   {
#     "region": "southeast",
#     "name": "Pitch’s",
#     "url": "https://wisconsinsupperclubs.com/supper-club/pitchs/",
#     "website": "https://www.pitchsribs.com",
#     "address": "1801 North Humboldt Avenue",
#     "city": "Milwaukee,",
#     "state": "WI",
#     "zip_code": "53202",
#     "phone": "414-272-9313"
#   },
#   {
#     "region": "southeast",
#     "name": "Plier’s Full Circle",
#     "url": "https://wisconsinsupperclubs.com/supper-club/pliers-full-circle/",
#     "website": "https://www.fullcirclerestaurant.com",
#     "address": "3704 Highland Drive",
#     "city": "Port Washington,",
#     "state": "WI",
#     "zip_code": "53074",
#     "phone": "262-261-5050"
#   },
#   {
#     "region": "southeast",
#     "name": "Range Line Inn",
#     "url": "https://wisconsinsupperclubs.com/supper-club/range-line-inn/",
#     "website": "https://www.facebook.com/TheRangeLineInn/",
#     "address": "2635 West Mequon Road",
#     "city": "Mequon",
#     "state": "WI",
#     "zip_code": "53092",
#     "phone": "262-242-0530"
#   },
#   {
#     "region": "southeast",
#     "name": "Red Circle Inn",
#     "url": "https://wisconsinsupperclubs.com/supper-club/red-circle-inn/",
#     "website": "https://www.redcircleinn.com",
#     "address": "N44W33013 Watertown Plank Rd",
#     "city": "Nashotah",
#     "state": "WI",
#     "zip_code": "53058",
#     "phone": "262-367-4883"
#   },
#   {
#     "region": "southeast",
#     "name": "Relish Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/relish-supper-club/",
#     "website": "https://relishsupperclub.com",
#     "address": "N116W15841 Main Street",
#     "city": "Germantown",
#     "state": "WI",
#     "zip_code": "53022",
#     "phone": "262-415-7043"
#   },
#   {
#     "region": "southeast",
#     "name": "Sandra’s on the Park",
#     "url": "https://wisconsinsupperclubs.com/supper-club/sandras-on-the-park/",
#     "website": "http://www.sandrasonthepark.com",
#     "address": "10049 West Forest Home Avenue",
#     "city": "Hales Corners,",
#     "state": "WI",
#     "zip_code": "53130",
#     "phone": "414-235-8889"
#   },
#   {
#     "region": "southeast",
#     "name": "Schaumburg Dinner Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/schaumburg-dinner-club/",
#     "website": "https://www.facebook.com/pages/category/American-Restaurant/Schaumburg-Dinner-Club-115738521780173/",
#     "address": "N11935 County Road A",
#     "city": "Randolph,",
#     "state": "WI",
#     "zip_code": "53956",
#     "phone": "920-928-3348"
#   },
#   {
#     "region": "southeast",
#     "name": "Shores of Fox Lake, The",
#     "url": "https://wisconsinsupperclubs.com/supper-club/the-shores-of-fox-lake/",
#     "website": "http://www.theshoresoffoxlake.com/",
#     "address": "N10604 Chief Kuno Trail",
#     "city": "Fox Lake,",
#     "state": "WI",
#     "zip_code": "53933",
#     "phone": "920-928-2576"
#   },
#   {
#     "region": "southeast",
#     "name": "Silver Lake Country Inn",
#     "url": "https://wisconsinsupperclubs.com/supper-club/silver-lake-country-inn/",
#     "website": "http://silverlakecountryinn.com",
#     "address": "5602 Peters Drive",
#     "city": "West Bend,",
#     "state": "WI",
#     "zip_code": "53095",
#     "phone": "262-338-7975"
#   },
#   {
#     "region": "southeast",
#     "name": "Stagecoach Inn **",
#     "url": "https://wisconsinsupperclubs.com/supper-club/stagecoach-inn/",
#     "website": "https://facebook.com/dinneratstagecoach",
#     "address": "11946 North State Road 26",
#     "city": "Fort Atkinson,",
#     "state": "WI",
#     "zip_code": "53538",
#     "phone": "608-868-3850"
#   },
#   {
#     "region": "southeast",
#     "name": "Steakout, The †",
#     "url": "https://wisconsinsupperclubs.com/supper-club/the-steakout-%e2%80%a0/",
#     "website": "http://www.greendalesteakout.com",
#     "address": "6300 Industrial Loop",
#     "city": "Greendale,",
#     "state": "WI",
#     "zip_code": "53129",
#     "phone": "414-421-7200"
#   },
#   {
#     "region": "southeast",
#     "name": "Timmer’s Resort",
#     "url": "https://wisconsinsupperclubs.com/supper-club/timmers-resort/",
#     "website": "https://timmersresort.com",
#     "address": "5151 Timmer Bay Road",
#     "city": "West Bend,",
#     "state": "WI",
#     "zip_code": "53095",
#     "phone": "262-338-7710"
#   },
#   {
#     "region": "southeast",
#     "name": "Village Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/village-supper-club/",
#     "website": "https://villagesupperclubdelavan.com",
#     "address": "1725 South Shore Road",
#     "city": "Delavan,",
#     "state": "WI",
#     "zip_code": "53115",
#     "phone": "262-456-3400"
#   },
#   {
#     "region": "southeast",
#     "name": "Village Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/village-supper-club-2/",
#     "website": "http://villagesupperclub.com/",
#     "address": "10909 Sheridan Road",
#     "city": "Pleasant Prairie,",
#     "state": "WI",
#     "zip_code": "53185",
#     "phone": "262-697-2847"
#   },
#   {
#     "region": "southeast",
#     "name": "Voelker’s Steak House",
#     "url": "https://wisconsinsupperclubs.com/supper-club/voelkers-steak-house/",
#     "website": "http://places.singleplatform.com/voelkers-steak-house/menu",
#     "address": "415 East South Street",
#     "city": "Beaver Dam,",
#     "state": "WI",
#     "zip_code": "53916",
#     "phone": "920-885-9924"
#   },
#   {
#     "region": "southeast",
#     "name": "Wayside Inn, The",
#     "url": "https://wisconsinsupperclubs.com/supper-club/wayside-inn/",
#     "website": "https://www.facebook.com/jeffersonwi/",
#     "address": "W4820 Hwy 18",
#     "city": "Jefferson",
#     "state": "WI",
#     "zip_code": "53549",
#     "phone": "920-674-6766"
#   },
#   {
#     "region": "southeast",
#     "name": "Wilmot Stage Stop",
#     "url": "https://wisconsinsupperclubs.com/supper-club/wilmot-stage-stop/",
#     "website": "https://www.wilmotstagestop.com",
#     "address": "30646 113th Street",
#     "city": "Wilmot,",
#     "state": "WI",
#     "zip_code": "53192",
#     "phone": "262-862-6212"
#   },
#   {
#     "region": "southeast",
#     "name": "Wisco Supper Club, The",
#     "url": "https://wisconsinsupperclubs.com/supper-club/the-wisco-supper-club/",
#     "website": "https://www.thewiscosupperclub.com",
#     "address": "W3295 County Road Y",
#     "city": "Lomira",
#     "state": "WI",
#     "zip_code": "53048",
#     "phone": "920-583-4351"
#   },
#   {
#     "region": "southwest",
#     "name": "3 Mile House *†",
#     "url": "https://wisconsinsupperclubs.com/supper-club/3-mile-house-%e2%80%a0/",
#     "website": "https://3milehouse.com/",
#     "address": "370 Wisconsin 35",
#     "city": "Hazel Green,",
#     "state": "WI",
#     "zip_code": "53811",
#     "phone": "608-748-4455"
#   },
#   {
#     "region": "southwest",
#     "name": "615 Club, The **",
#     "url": "https://wisconsinsupperclubs.com/supper-club/the-615-club/",
#     "website": "http://the615club.com/",
#     "address": "615 Broad Street",
#     "city": "Beloit,",
#     "state": "WI",
#     "zip_code": "53511",
#     "phone": "608-364-4615"
#   },
#   {
#     "region": "southwest",
#     "name": "Arthur’s Supper Club **",
#     "url": "https://wisconsinsupperclubs.com/supper-club/arthurs-supper-club/",
#     "website": "https://arthurssupperclub.com/",
#     "address": "E4885 US Highway 14",
#     "city": "Spring Green,",
#     "state": "WI",
#     "zip_code": "53588",
#     "phone": "608-588-2521"
#   },
#   {
#     "region": "southwest",
#     "name": "Badger Crossing",
#     "url": "https://wisconsinsupperclubs.com/supper-club/badger-crossing/",
#     "website": "https://www.badgercrossing.com",
#     "address": "909 Front Street",
#     "city": "Cashton",
#     "state": "WI",
#     "zip_code": "54619",
#     "phone": "608-654-5706"
#   },
#   {
#     "region": "southwest",
#     "name": "Benedetti’s Club 51 *†",
#     "url": "https://wisconsinsupperclubs.com/supper-club/benedettis-club-51-%e2%80%a0/",
#     "website": "https://benedettisclub51.wordpress.com/menu/",
#     "address": "3232 S Riverside Dr",
#     "city": "Beloit,",
#     "state": "WI",
#     "zip_code": "53511",
#     "phone": "608-362-9917"
#   },
#   {
#     "region": "southwest",
#     "name": "Buckhorn Supper Club *†",
#     "url": "https://wisconsinsupperclubs.com/supper-club/buckhorn-supper-club-%e2%80%a0/",
#     "website": "https://buckhornsupperclub.com",
#     "address": "11802 N Charley Bluff Rd",
#     "city": "Milton,",
#     "state": "WI",
#     "zip_code": "53563",
#     "phone": "608-868-2653"
#   },
#   {
#     "region": "southwest",
#     "name": "Butterfly Club, The *†",
#     "url": "https://wisconsinsupperclubs.com/supper-club/the-butterfly-club-%e2%80%a0/",
#     "website": "http://www.butterflyclub.us/",
#     "address": "5246 E County Road X",
#     "city": "Beloit,",
#     "state": "WI",
#     "zip_code": "53511",
#     "phone": "608-362-8577"
#   },
#   {
#     "region": "southwest",
#     "name": "Chop’s Kall Inn *†",
#     "url": "https://wisconsinsupperclubs.com/supper-club/chops-kall-inn-%e2%80%a0/",
#     "website": "https://www.chopskallinn.com",
#     "address": "4089 Sandy Hook Rd.",
#     "city": "Hazel Green,",
#     "state": "WI",
#     "zip_code": "53811",
#     "phone": "608-748-4393"
#   },
#   {
#     "region": "southwest",
#     "name": "Cimaroli’s Supper Club *†",
#     "url": "https://wisconsinsupperclubs.com/supper-club/cimarolis-supper-club-%e2%80%a0/",
#     "website": "http://www.cimarolis.com/",
#     "address": "W11793 WI-127",
#     "city": "Portage,",
#     "state": "WI",
#     "zip_code": "53901",
#     "phone": "608-742-2238"
#   },
#   {
#     "region": "southwest",
#     "name": "Club 60",
#     "url": "https://wisconsinsupperclubs.com/supper-club/club-60/",
#     "website": "http://www.club60supperclub.com",
#     "address": "W2164 State Rd 60",
#     "city": "Columbus,",
#     "state": "WI",
#     "zip_code": "53925",
#     "phone": "920-623-3113"
#   },
#   {
#     "region": "southwest",
#     "name": "Club Oasis **",
#     "url": "https://wisconsinsupperclubs.com/supper-club/club-oasis/",
#     "website": "http://cluboasissparta.com/",
#     "address": "11345 State Highway 21",
#     "city": "Sparta,",
#     "state": "WI",
#     "zip_code": "54656",
#     "phone": "608-269-2644"
#   },
#   {
#     "region": "southwest",
#     "name": "Cottonwood, The",
#     "url": "https://wisconsinsupperclubs.com/supper-club/the-cottonwood/",
#     "website": "http://cottonwoodsupperclub.com",
#     "address": "4716 Green River Rd",
#     "city": "Fennimore,",
#     "state": "WI",
#     "zip_code": "53809",
#     "phone": "608-822-631"
#   },
#   {
#     "region": "southwest",
#     "name": "Country Heights Supper Club *†",
#     "url": "https://wisconsinsupperclubs.com/supper-club/country-heights-supper-club-%e2%80%a0/",
#     "website": "http://countryheightssupperclubandmotel.com/",
#     "address": "1152 Badger Rd",
#     "city": "Hazel Green,",
#     "state": "WI",
#     "zip_code": "53811",
#     "phone": "608-748-4687"
#   },
#   {
#     "region": "southwest",
#     "name": "Crossroads Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/crossroads-supper-club/",
#     "website": "https://www.crossroads80anda.com",
#     "address": "9315 State Road 80",
#     "city": "Platteville,",
#     "state": "WI",
#     "zip_code": "53818",
#     "phone": "608-348-7899"
#   },
#   {
#     "region": "southwest",
#     "name": "Del Bar, The **",
#     "url": "https://wisconsinsupperclubs.com/supper-club/the-del-bar/",
#     "website": "http://del-bar.com/",
#     "address": "800 Wisconsin Dells Parkway",
#     "city": "Wisconsin Dells,",
#     "state": "WI",
#     "zip_code": "53965",
#     "phone": "608-253-1861"
#   },
#   {
#     "region": "southwest",
#     "name": "Delaney’s **",
#     "url": "https://wisconsinsupperclubs.com/supper-club/delaneys/",
#     "website": "https://experiencedelaneys.com",
#     "address": "449 Grand Canyon Drive",
#     "city": "Madison,",
#     "state": "WI",
#     "zip_code": "53719",
#     "phone": "608-833-7337"
#   },
#   {
#     "region": "southwest",
#     "name": "Digger’s Sting",
#     "url": "https://wisconsinsupperclubs.com/supper-club/diggers-sting/",
#     "website": "https://diggerssting.com",
#     "address": "122 3rd Street N",
#     "city": "La Crosse,",
#     "state": "WI",
#     "zip_code": "54601",
#     "phone": "608-782-3796"
#   },
#   {
#     "region": "southwest",
#     "name": "Dorf Haus Supper Club *†",
#     "url": "https://wisconsinsupperclubs.com/supper-club/dorf-haus-supper-club-%e2%80%a0/",
#     "website": "http://www.foodspot.com/Clients/WI/SaukCity/DorfHausSupperClub/default.aspx?accid=19510",
#     "address": "8931 County Hwy Y",
#     "city": "Sauk City,",
#     "state": "WI",
#     "zip_code": "53583",
#     "phone": "608-643-3980"
#   },
#   {
#     "region": "southwest",
#     "name": "Driftless Social",
#     "url": "https://wisconsinsupperclubs.com/supper-club/driftless-social/",
#     "website": "https://www.driftlesssocial.com",
#     "address": "128 East Main Street",
#     "city": "Mt. Horeb",
#     "state": "WI",
#     "zip_code": "53572",
#     "phone": "608-437-8464"
#   },
#   {
#     "region": "southwest",
#     "name": "Drugan’s Castle Mound",
#     "url": "https://wisconsinsupperclubs.com/supper-club/drugans-castle-mound/",
#     "website": "https://drugans.com",
#     "address": "W7665 Sylvester Road",
#     "city": "Holmen,",
#     "state": "WI",
#     "zip_code": "54636",
#     "phone": "608-526-4144"
#   },
#   {
#     "region": "southwest",
#     "name": "Fish Tales",
#     "url": "https://wisconsinsupperclubs.com/supper-club/fish-tales/",
#     "website": "https://www.fishtalesrestaurant.com",
#     "address": "W12690 Hwy 188",
#     "city": "Lodi,",
#     "state": "WI",
#     "zip_code": "53555",
#     "phone": "608-592-4266"
#   },
#   {
#     "region": "southwest",
#     "name": "Fitz’s on the Lake",
#     "url": "https://wisconsinsupperclubs.com/supper-club/fitzs-on-the-lake/",
#     "website": "https://fitzsonthelake.com",
#     "address": "W11602 County Road V",
#     "city": "Lodi,",
#     "state": "WI",
#     "zip_code": "53555",
#     "phone": "608-592-3302"
#   },
#   {
#     "region": "southwest",
#     "name": "Fredrick’s Supper Club †",
#     "url": "https://wisconsinsupperclubs.com/supper-club/fredricks-supper-club-%e2%80%a0/",
#     "website": "https://www.facebook.com/FredricksSupperClub/",
#     "address": "118 Merchant Row",
#     "city": "Milton,",
#     "state": "WI",
#     "zip_code": "53563",
#     "phone": "608-868-2966"
#   },
#   {
#     "region": "southwest",
#     "name": "Freighthouse Restaurant",
#     "url": "https://wisconsinsupperclubs.com/supper-club/freighthouse-restaurant/",
#     "website": "https://www.freighthouserestaurant.com",
#     "address": "107 Vine Street",
#     "city": "La Crosse,",
#     "state": "WI",
#     "zip_code": "54601",
#     "phone": "608-784-6211"
#   },
#   {
#     "region": "southwest",
#     "name": "Green Acres Supper Club **",
#     "url": "https://wisconsinsupperclubs.com/supper-club/green-acres-supper-club/",
#     "website": "http://greenacresrestaurant.com/",
#     "address": "7438 State Road 78",
#     "city": "Sauk City,",
#     "state": "WI",
#     "zip_code": "53583",
#     "phone": "608-643-2305"
#   },
#   {
#     "region": "southwest",
#     "name": "Green Lantern Restaurant",
#     "url": "https://wisconsinsupperclubs.com/supper-club/green-lantern-restaurant/",
#     "website": "https://thegreenlanternrestaurant.com",
#     "address": "4412 Siggelkow Road",
#     "city": "McFarland,",
#     "state": "WI",
#     "zip_code": "53558",
#     "phone": "608-838-4730"
#   },
#   {
#     "region": "southwest",
#     "name": "Hi Point Steakhouse †",
#     "url": "https://wisconsinsupperclubs.com/supper-club/hi-point-steakhouse-%e2%80%a0/",
#     "website": "https://www.hipointsteakhouse.com/",
#     "address": "6900 County Road HHH",
#     "city": "Ridgeway,",
#     "state": "WI",
#     "zip_code": "53582",
#     "phone": "608-924-2819"
#   },
#   {
#     "region": "southwest",
#     "name": "Hideaway Acres",
#     "url": "https://wisconsinsupperclubs.com/supper-club/hideaway-acres/",
#     "website": "https://www.facebook.com/pages/Hideaway-Acres-Supper-Club/117294844956227",
#     "address": "4825 Bennett Road",
#     "city": "Benton,",
#     "state": "WI",
#     "zip_code": "53803",
#     "phone": "608-759-4410"
#   },
#   {
#     "region": "southwest",
#     "name": "Hilltop, The †",
#     "url": "https://wisconsinsupperclubs.com/supper-club/the-hilltop-%e2%80%a0/",
#     "website": "http://thehilltopcp.com",
#     "address": "4173 Hwy P",
#     "city": "Cross Plains,",
#     "state": "WI",
#     "zip_code": "53528",
#     "phone": "608-798-2893"
#   },
#   {
#     "region": "southwest",
#     "name": "House of Embers",
#     "url": "https://wisconsinsupperclubs.com/supper-club/house-of-embers/",
#     "website": "https://www.houseofembers.com",
#     "address": "935 Wisconsin Dells Parkway",
#     "city": "Wisconsin Dells,",
#     "state": "WI",
#     "zip_code": "53965",
#     "phone": "608-253-6411"
#   },
#   {
#     "region": "southwest",
#     "name": "Ishnala *†",
#     "url": "https://wisconsinsupperclubs.com/supper-club/ishnala-%e2%80%a0/",
#     "website": "http://www.ishnala.com",
#     "address": "S2011 Ishnala Road",
#     "city": "Lake Delton,",
#     "state": "WI",
#     "zip_code": "53940",
#     "phone": "608-253-1771"
#   },
#   {
#     "region": "southwest",
#     "name": "Jones’ Black Angus *†",
#     "url": "https://wisconsinsupperclubs.com/supper-club/jones-black-angus-%e2%80%a0/",
#     "website": "http://jonesblackangus.com",
#     "address": "37640 Hwy 18",
#     "city": "Prairie du Chien,",
#     "state": "WI",
#     "zip_code": "53821",
#     "phone": "608-326-2222"
#   },
#   {
#     "region": "southwest",
#     "name": "Kickapoo Creekside",
#     "url": "https://wisconsinsupperclubs.com/supper-club/kickapoo-creekside/",
#     "website": "https://kickapoocreekside.com",
#     "address": "817 West Kickapoo Street",
#     "city": "Readstown,",
#     "state": "WI",
#     "zip_code": "54652",
#     "phone": "608-629-5565"
#   },
#   {
#     "region": "southwest",
#     "name": "Lake House Inn",
#     "url": "https://wisconsinsupperclubs.com/supper-club/lake-house-inn/",
#     "website": "https://www.lakehouseinnedgerton.com/",
#     "address": "1612 East Hotel Drive",
#     "city": "Edgerton,",
#     "state": "WI",
#     "zip_code": "53534",
#     "phone": "608-235-2771"
#   },
#   {
#     "region": "southwest",
#     "name": "Louisburg Junction Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/louisburg-junction-supper-club/",
#     "website": "https://www.louisburgjunction.com",
#     "address": "2061 Louisburg Road",
#     "city": "Cuba City,",
#     "state": "WI",
#     "zip_code": "53807",
#     "phone": "608-774-3663"
#   },
#   {
#     "region": "southwest",
#     "name": "Maple Tree Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/maple-tree-supper-club/",
#     "website": "https://mapletreesupperclub.com/",
#     "address": "6010 US Hwy 51",
#     "city": "McFarland,",
#     "state": "WI",
#     "zip_code": "53558",
#     "phone": "608-838-5888"
#   },
#   {
#     "region": "southwest",
#     "name": "Mariner’s",
#     "url": "https://wisconsinsupperclubs.com/supper-club/mariners/",
#     "website": "https://marinersmadison.com",
#     "address": "5339 Lighthouse Bay Drive",
#     "city": "Madison,",
#     "state": "WI",
#     "zip_code": "53704",
#     "phone": "608-246-3120"
#   },
#   {
#     "region": "southwest",
#     "name": "Old Towne Inn **",
#     "url": "https://wisconsinsupperclubs.com/supper-club/old-towne-inn/",
#     "website": "https://www.oldtowneinnwestby.com/",
#     "address": "100 East Old Town Road",
#     "city": "Westby,",
#     "state": "WI",
#     "zip_code": "54667",
#     "phone": "608-634-3991"
#   },
#   {
#     "region": "southwest",
#     "name": "Owl’s Nest",
#     "url": "https://wisconsinsupperclubs.com/supper-club/owls-nest/",
#     "website": "https://owlsnestwi.com",
#     "address": "617 East North Street",
#     "city": "Poynette,",
#     "state": "WI",
#     "zip_code": "53955",
#     "phone": "608-635-2299"
#   },
#   {
#     "region": "southwest",
#     "name": "Red’s Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/reds-supper-club/",
#     "website": "https://www.facebook.com/Reds-Supper-Club-148288721881937",
#     "address": "27569 Hwy 81",
#     "city": "Cuba City,",
#     "state": "WI",
#     "zip_code": "53807",
#     "phone": "608-762-5406"
#   },
#   {
#     "region": "southwest",
#     "name": "Rex’s Innkeeper",
#     "url": "https://wisconsinsupperclubs.com/supper-club/rexs-innkeeper/",
#     "website": "https://rexsinnkeeper.com",
#     "address": "301 North Century Avenue",
#     "city": "Waunakee,",
#     "state": "WI",
#     "zip_code": "53597",
#     "phone": "608-849-5011"
#   },
#   {
#     "region": "southwest",
#     "name": "Ridge, The",
#     "url": "https://wisconsinsupperclubs.com/supper-club/the-ridge/",
#     "website": "https://www.facebook.com/theridgerestaurant3/",
#     "address": "W2782 Hwy 33",
#     "city": "La Crosse,",
#     "state": "WI",
#     "zip_code": "54601",
#     "phone": "608-788-3969"
#   },
#   {
#     "region": "southwest",
#     "name": "Rocky’s Supper Club *†",
#     "url": "https://wisconsinsupperclubs.com/supper-club/rockys-supper-club-%e2%80%a0/",
#     "website": "https://www.facebook.com/RockysSupperClub/",
#     "address": "101 South Main Street",
#     "city": "Stoddard,",
#     "state": "WI",
#     "zip_code": "54658",
#     "phone": "608-457-2111"
#   },
#   {
#     "region": "southwest",
#     "name": "Suzy’s Steak & Seafood",
#     "url": "https://wisconsinsupperclubs.com/supper-club/suzys-steak-seafood/",
#     "website": "https://suzysportage.com",
#     "address": "2701 County Road CX",
#     "city": "Portage,",
#     "state": "WI",
#     "zip_code": "53901",
#     "phone": "608-742-8400"
#   },
#   {
#     "region": "southwest",
#     "name": "Toby’s Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/tobys-supper-club/",
#     "website": "http://www.tobyssupperclub.com/Home.html",
#     "address": "3717 South Dutch Mill Road",
#     "city": "Madison,",
#     "state": "WI",
#     "zip_code": "53718",
#     "phone": "608-222-6913"
#   },
#   {
#     "region": "southwest",
#     "name": "Tornado Club Steak House *†",
#     "url": "https://wisconsinsupperclubs.com/supper-club/tornado-club-steak-house-%e2%80%a0/",
#     "website": "http://www.tornadosteakhouse.com/",
#     "address": "116 South Hamilton Street",
#     "city": "Madison,",
#     "state": "WI",
#     "zip_code": "53703",
#     "phone": "608-256-3570"
#   },
#   {
#     "region": "southwest",
#     "name": "Turn Key Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/turn-key-supper-club/",
#     "website": "https://www.turnkeymadison.com",
#     "address": "1344 East Washington Avenue",
#     "city": "Madison",
#     "state": "WI",
#     "zip_code": "53703",
#     "phone": "608-416-1109"
#   },
#   {
#     "region": "southwest",
#     "name": "Village Bar Supper Club, The **",
#     "url": "https://wisconsinsupperclubs.com/supper-club/the-village-bar-supper-club/",
#     "website": "http://villagebar.webstarts.com/",
#     "address": "3410 County Road HHH",
#     "city": "Kieler,",
#     "state": "WI",
#     "zip_code": "53812",
#     "phone": "608-568-3004"
#   },
#   {
#     "region": "southwest",
#     "name": "Village Inn",
#     "url": "https://wisconsinsupperclubs.com/supper-club/village-inn/",
#     "website": "https://www.facebook.com/p/Village-Inn-Pub-Eatery-100057630871993/",
#     "address": "1601 Bangor Street",
#     "city": "Bangor",
#     "state": "WI",
#     "zip_code": "54614",
#     "phone": "608-486-2741"
#   },
#   {
#     "region": "southwest",
#     "name": "Westview Inn",
#     "url": "https://wisconsinsupperclubs.com/supper-club/westview-inn/",
#     "website": "https://www.facebook.com/pages/category/American-Restaurant/Westview-Inn-145895945450229/",
#     "address": "174 Leonard Street S",
#     "city": "West Salem,",
#     "state": "WI",
#     "zip_code": "54669",
#     "phone": "608-786-1336"
#   },
#   {
#     "region": "southwest",
#     "name": "Woodbine Inn",
#     "url": "https://wisconsinsupperclubs.com/supper-club/woodbine-inn/",
#     "website": "https://www.facebook.com/pages/category/American-Restaurant/Woodbine-Inn-247749015265585/",
#     "address": "N11091 19th Avenue",
#     "city": "Necedah,",
#     "state": "WI",
#     "zip_code": "54646",
#     "phone": "608-565-2122"
#   },
#   {
#     "region": "southwest",
#     "name": "Zeman’s Old Highway House",
#     "url": "https://wisconsinsupperclubs.com/supper-club/zemans-old-highway-house/",
#     "website": "https://zemans-hh.com",
#     "address": "620 West Pine Street",
#     "city": "Baraboo,",
#     "state": "WI",
#     "zip_code": "53913",
#     "phone": "608-448-6950"
#   },
#   {
#     "region": "northeast",
#     "name": "Alexander’s",
#     "url": "https://wisconsinsupperclubs.com/supper-club/alexanders/",
#     "website": "https://alexandersofdoorcounty.com",
#     "address": "3667 WI-42",
#     "city": "Fish Creek,",
#     "state": "WI",
#     "zip_code": "54212",
#     "phone": "920-868-3532"
#   },
#   {
#     "region": "northeast",
#     "name": "Altona Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/altona-supper-club/",
#     "website": "http://www.altonasupperclub.com",
#     "address": "2306 Calumet Drive",
#     "city": "New Holstein,",
#     "state": "WI",
#     "zip_code": "53061",
#     "phone": "920-898-5255"
#   },
#   {
#     "region": "northeast",
#     "name": "Anderson’s Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/andersons-supper-club/",
#     "website": "https://www.facebook.com/AndersonsSupperClub/",
#     "address": "15695 State Hwy 32",
#     "city": "Lakewood,",
#     "state": "WI",
#     "zip_code": "53138",
#     "phone": "715-850-2717"
#   },
#   {
#     "region": "northeast",
#     "name": "Ballering, The",
#     "url": "https://wisconsinsupperclubs.com/supper-club/the-ballering/",
#     "website": "https://www.facebook.com/TheBallering/",
#     "address": "Milwaukee Street",
#     "city": "Kewaunee,",
#     "state": "WI",
#     "zip_code": "54216",
#     "phone": "920-388-6011"
#   },
#   {
#     "region": "northeast",
#     "name": "Bavarian Inn",
#     "url": "https://wisconsinsupperclubs.com/supper-club/bavarian-inn/",
#     "website": "https://www.menupix.com/wisconsin/restaurants/4900722/Bavarian-Inn-Supper-Club-Lena-WI",
#     "address": "104 East Main Street",
#     "city": "Lena,",
#     "state": "WI",
#     "zip_code": "53139",
#     "phone": "920-829-5168"
#   },
#   {
#     "region": "northeast",
#     "name": "Billy’s on Main",
#     "url": "https://wisconsinsupperclubs.com/supper-club/billys-on-main/",
#     "website": "https://www.facebook.com/billysonmain",
#     "address": "741 Main Street",
#     "city": "Luxemburg,",
#     "state": "WI",
#     "zip_code": "54217",
#     "phone": "920-845-2505"
#   },
#   {
#     "region": "northeast",
#     "name": "Black Otter Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/black-otter-supper-club/",
#     "website": "https://www.theblackottersupperclub.com",
#     "address": "503 South Nash Street",
#     "city": "Hortonville,",
#     "state": "WI",
#     "zip_code": "54944",
#     "phone": "920-779-6975"
#   },
#   {
#     "region": "northeast",
#     "name": "Blanck’s Supper Club †",
#     "url": "https://wisconsinsupperclubs.com/supper-club/blancks-supper-club-%e2%80%a0/",
#     "website": "http://www.blanckssupperclub.com",
#     "address": "W2655 County Road Q",
#     "city": "Malone,",
#     "state": "WI",
#     "zip_code": "54049",
#     "phone": "920-795-4484"
#   },
#   {
#     "region": "northeast",
#     "name": "Boarding House **",
#     "url": "https://wisconsinsupperclubs.com/supper-club/boarding-house/",
#     "website": "http://theboardinghousesupperclub.com/",
#     "address": "632 Main Street",
#     "city": "Suring,",
#     "state": "WI",
#     "zip_code": "54174",
#     "phone": "920-842-2490"
#   },
#   {
#     "region": "northeast",
#     "name": "Bob & Laura’s Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/bob-lauras-supper-club/",
#     "website": "https://www.facebook.com/bobandlauras/",
#     "address": "N4175 Alpine Lane",
#     "city": "Pound,",
#     "state": "WI",
#     "zip_code": "54161",
#     "phone": "920-897-4004"
#   },
#   {
#     "region": "northeast",
#     "name": "Brown’s Corner",
#     "url": "https://wisconsinsupperclubs.com/supper-club/browns-corner/",
#     "website": "https://www.brownscorner.net",
#     "address": "800 French Street",
#     "city": "Peshtigo,",
#     "state": "WI",
#     "zip_code": "54157",
#     "phone": "715-801-0045"
#   },
#   {
#     "region": "northeast",
#     "name": "Butte Des Morts Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/butte-des-morts-supper-club/",
#     "website": "http://www.buttedesmortssupperclub.com",
#     "address": "5756 Main Street",
#     "city": "Butte Des Morts,",
#     "state": "WI",
#     "zip_code": "54927",
#     "phone": "920-582-0665"
#   },
#   {
#     "region": "northeast",
#     "name": "Cattails Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/cattails-supper-club/",
#     "website": "https://www.facebook.com/people/Cattails-Supper-Club/61553397403460/",
#     "address": "6661 Brecklins Loop Road",
#     "city": "Larsen",
#     "state": "WI",
#     "zip_code": "54947",
#     "phone": "920-836-0279"
#   },
#   {
#     "region": "northeast",
#     "name": "Cedar Lodge",
#     "url": "https://wisconsinsupperclubs.com/supper-club/cedar-lodge/",
#     "website": "http://www.thecedarlodge.com/",
#     "address": "N10872 Hwy 151",
#     "city": "Calumetville,",
#     "state": "WI",
#     "zip_code": "53049",
#     "phone": "920-795-4574"
#   },
#   {
#     "region": "northeast",
#     "name": "Century Elm Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/century-elm-supper-club/",
#     "website": "https://www.centuryelm.com",
#     "address": "8300 County Road T",
#     "city": "Larsen,",
#     "state": "WI",
#     "zip_code": "54927",
#     "phone": "920-836-2022"
#   },
#   {
#     "region": "northeast",
#     "name": "Chissy’s Pub & Grill",
#     "url": "https://wisconsinsupperclubs.com/supper-club/chissys-pub-grill/",
#     "website": "http://chissys.com",
#     "address": "215 Hwy 28",
#     "city": "Waldo,",
#     "state": "WI",
#     "zip_code": "54927",
#     "phone": "920-528-8656"
#   },
#   {
#     "region": "northeast",
#     "name": "Club Chalet **",
#     "url": "https://wisconsinsupperclubs.com/supper-club/club-chalet/",
#     "website": "http://clubchalet.net/",
#     "address": "4642 Nicolet Drive",
#     "city": "Green Bay,",
#     "state": "WI",
#     "zip_code": "54311",
#     "phone": "920-866-2341"
#   },
#   {
#     "region": "northeast",
#     "name": "Colonial House Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/colonial-house-supper-club/",
#     "website": "http://www.colonialhousesupperclub.com",
#     "address": "N4330 County Road E",
#     "city": "Kaukauna,",
#     "state": "WI",
#     "zip_code": "54130",
#     "phone": "920-788-2622"
#   },
#   {
#     "region": "northeast",
#     "name": "Dan and Tim’s Riverside",
#     "url": "https://wisconsinsupperclubs.com/supper-club/dan-and-tims-riverside/",
#     "website": "https://www.facebook.com/Riverside.Dan.Tim/",
#     "address": "1010 Main Avenue",
#     "city": "Crivitz,",
#     "state": "WI",
#     "zip_code": "54114",
#     "phone": "715-854-3281"
#   },
#   {
#     "region": "northeast",
#     "name": "Dick and Joan’s Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/dick-and-joans-supper-club/",
#     "website": "https://www.facebook.com/dickandjoans/",
#     "address": "220 North Lynndale Drive",
#     "city": "Appleton,",
#     "state": "WI",
#     "zip_code": "54914",
#     "phone": "920-731-8855"
#   },
#   {
#     "region": "northeast",
#     "name": "Donny’s Glidden Lodge †",
#     "url": "https://wisconsinsupperclubs.com/supper-club/donnys-glidden-lodge-%e2%80%a0/",
#     "website": "https://donnysgliddenlodge.com",
#     "address": "4670 Glidden Road",
#     "city": "Sturgeon Bay,",
#     "state": "WI",
#     "zip_code": "54235",
#     "phone": "920-746-9460"
#   },
#   {
#     "region": "northeast",
#     "name": "Embers 1871",
#     "url": "https://wisconsinsupperclubs.com/supper-club/embers-1871/",
#     "website": "http://www.embers1871.com",
#     "address": "W3529 County Road B",
#     "city": "Peshtigo,",
#     "state": "WI",
#     "zip_code": "54157",
#     "phone": "715-801-0023"
#   },
#   {
#     "region": "northeast",
#     "name": "English Inn, The",
#     "url": "https://wisconsinsupperclubs.com/supper-club/the-english-inn/",
#     "website": "https://theenglishinn.com",
#     "address": "3713 Hwy 42",
#     "city": "Fish Creek,",
#     "state": "WI",
#     "zip_code": "54212",
#     "phone": "920-868-3076"
#   },
#   {
#     "region": "northeast",
#     "name": "Five Pillars Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/five-pillars-supper-club/",
#     "website": "http://www.fivepillarssupperclub.com",
#     "address": "W2290 Hwy K",
#     "city": "Random Lake,",
#     "state": "WI",
#     "zip_code": "53075",
#     "phone": "920-994-4336"
#   },
#   {
#     "region": "northeast",
#     "name": "Geno’s Steakhouse †",
#     "url": "https://wisconsinsupperclubs.com/supper-club/genos-steakhouse-%e2%80%a0/",
#     "website": "http://www.genossteakhouse47.com",
#     "address": "N8755 Old Hwy 47",
#     "city": "Black Creek,",
#     "state": "WI",
#     "zip_code": "54106",
#     "phone": "920-439-1265"
#   },
#   {
#     "region": "northeast",
#     "name": "George’s Steakhouse",
#     "url": "https://wisconsinsupperclubs.com/supper-club/georges-steakhouse/",
#     "website": "http://www.georgessteakhouseappleton.com",
#     "address": "2208 South Memorial Drive",
#     "city": "Appleton,",
#     "state": "WI",
#     "zip_code": "54915",
#     "phone": "920-733-4939"
#   },
#   {
#     "region": "northeast",
#     "name": "Gib’s on the Lake **",
#     "url": "https://wisconsinsupperclubs.com/supper-club/gibs-on-the-lake/",
#     "website": "http://gibsonthelake.com/",
#     "address": "N110 Hwy 42",
#     "city": "Kewaunee,",
#     "state": "WI",
#     "zip_code": "54216",
#     "phone": "920-776-1551"
#   },
#   {
#     "region": "northeast",
#     "name": "Gobbler’s Knob",
#     "url": "https://wisconsinsupperclubs.com/supper-club/gobblers-knob/",
#     "website": "https://gobblersknob.net",
#     "address": "101 North Military Road",
#     "city": "Stockbridge,",
#     "state": "WI",
#     "zip_code": "53088",
#     "phone": "920-439-1265"
#   },
#   {
#     "region": "northeast",
#     "name": "Granary Supper Club, The",
#     "url": "https://wisconsinsupperclubs.com/supper-club/1376/",
#     "website": "https://www.facebook.com/thegranarysupperclub/",
#     "address": "N586 Military Road",
#     "city": "Sherwood,",
#     "state": "WI",
#     "zip_code": "54169",
#     "phone": "920-989-1233"
#   },
#   {
#     "region": "northeast",
#     "name": "Haase’s Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/haases-supper-club/",
#     "website": "https://www.facebook.com/HaasesSupperClub/",
#     "address": "9497 County Hwy D",
#     "city": "Winneconne,",
#     "state": "WI",
#     "zip_code": "54986",
#     "phone": "920-685-2721"
#   },
#   {
#     "region": "northeast",
#     "name": "Harbor Fish Market & Grille",
#     "url": "https://wisconsinsupperclubs.com/supper-club/harbor-fish-market-grille/",
#     "website": "https://harborfishmarket-grille.com",
#     "address": "8080 Highway 57",
#     "city": "Baileys Harbor,",
#     "state": "WI",
#     "zip_code": "54202",
#     "phone": "920-839-9999"
#   },
#   {
#     "region": "northeast",
#     "name": "Harborside",
#     "url": "https://wisconsinsupperclubs.com/supper-club/harborside/",
#     "website": "https://harborsiderestaurantwi.com",
#     "address": "701 York Street",
#     "city": "Manitowoc,",
#     "state": "WI",
#     "zip_code": "54220",
#     "phone": "920-684-5711"
#   },
#   {
#     "region": "northeast",
#     "name": "Hillcrest Lodge Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/hillcrest-lodge-supper-club/",
#     "website": "https://www.facebook.com/HillcrestLodgeWI/",
#     "address": "16704 Nicolet Road",
#     "city": "Townsend,",
#     "state": "WI",
#     "zip_code": "54175",
#     "phone": "715-276-1500"
#   },
#   {
#     "region": "northeast",
#     "name": "Hotel Seymour Supper Club",
# ...
#     "state": "WI",
#     "zip_code": "54531",
#     "phone": "715-453-3678"
#   },
#   {
#     "region": "north-central",
#     "name": "Wolff’s River Inn †",
#     "url": "https://wisconsinsupperclubs.com/supper-club/wolffs-river-inn-%e2%80%a0/",
#     "website": "https://www.facebook.com/Wolffs-River-Inn-130780230273136/",
#     "address": "W8700 County Road K",
#     "city": "Elcho,",
#     "state": "WI",
#     "zip_code": "54428",
#     "phone": "715-275-3902"
#   },
#   {
#     "region": "northwest",
#     "name": "5 O’Clock Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/5-oclock-club/",
#     "website": "https://www.facebook.com/thefiveoclock/",
#     "address": "2639 7th Street",
#     "city": "Cumberland,",
#     "state": "WI",
#     "zip_code": "54829",
#     "phone": "715-822-2924"
#   },
#   {
#     "region": "northwest",
#     "name": "Beedles Bar & Restaurant",
#     "url": "https://wisconsinsupperclubs.com/supper-club/beedles-bar-restaurant/",
#     "website": "https://www.beedlesbar.com/",
#     "address": "W24966 Hwy 54",
#     "city": "Galesville,",
#     "state": "WI",
#     "zip_code": "54630",
#     "phone": "608-539-2251"
#   },
#   {
#     "region": "northwest",
#     "name": "Buckhorn Bar, The",
#     "url": "https://wisconsinsupperclubs.com/supper-club/the-buckhorn-bar/",
#     "website": "https://www.facebook.com/buckhornexeland",
#     "address": "11010 Hwy 48",
#     "city": "Exeland,",
#     "state": "WI",
#     "zip_code": "54835",
#     "phone": "715-943-2781"
#   },
#   {
#     "region": "northwest",
#     "name": "Buskey Bay Resort",
#     "url": "https://wisconsinsupperclubs.com/supper-club/buskey-bay-resort/",
#     "website": "https://buskeybayresort.com/dining/",
#     "address": "65445 County Hwy H",
#     "city": "Iron River,",
#     "state": "WI",
#     "zip_code": "54847",
#     "phone": "715-372-4580"
#   },
#   {
#     "region": "northwest",
#     "name": "Castle Hill Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/castle-hill-supper-club/",
#     "website": "http://www.castlehillsupperclub.com/",
#     "address": "N9581 Hwy 12",
#     "city": "Merrillan,",
#     "state": "WI",
#     "zip_code": "54754",
#     "phone": "715-333-5901"
#   },
#   {
#     "region": "northwest",
#     "name": "Cousin’s Hide-A-Way",
#     "url": "https://wisconsinsupperclubs.com/supper-club/cousins-hide-a-way/",
#     "website": "https://www.facebook.com/people/Cousins-Hide-A-Way/100063561400859/",
#     "address": "209 County Road SS",
#     "city": "Haugen,",
#     "state": "WI",
#     "zip_code": "54841",
#     "phone": "715-234-6555"
#   },
#   {
#     "region": "northwest",
#     "name": "Dalles House, The",
#     "url": "https://wisconsinsupperclubs.com/supper-club/the-dalles-house/",
#     "website": "http://www.dalleshouse.com",
#     "address": "720 South Vincent Street",
#     "city": "St. Croix Falls,",
#     "state": "WI",
#     "zip_code": "54024",
#     "phone": "715-483-3246"
#   },
#   {
#     "region": "northwest",
#     "name": "Ding-A-Ling Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/ding-a-ling-supper-club/",
#     "website": "https://www.facebook.com/people/Dingaling-Supper-Club/100063499515779/",
#     "address": "1711 Hwy 51",
#     "city": "Mercer,",
#     "state": "WI",
#     "zip_code": "54547",
#     "phone": "715-476-2270"
#   },
#   {
#     "region": "northwest",
#     "name": "Dreamland Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/dreamland-supper-club/",
#     "website": "http://www.dreamlandsupperclub.com/",
#     "address": "4368 South County Road East",
#     "city": "South Range,",
#     "state": "WI",
#     "zip_code": "54874",
#     "phone": "715-398-3706"
#   },
#   {
#     "region": "northwest",
#     "name": "Eddie’s",
#     "url": "https://wisconsinsupperclubs.com/supper-club/eddies/",
#     "website": "http://eddiesribs.net/",
#     "address": "5221 East 4th Street",
#     "city": "Superior,",
#     "state": "WI",
#     "zip_code": "54880",
#     "phone": "715-398-0191"
#   },
#   {
#     "region": "northwest",
#     "name": "Evergreens Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/evergreens-supper-club/",
#     "website": "https://www.facebook.com/EvergreensSupperClubLLC/",
#     "address": "1095 Apollo Road",
#     "city": "Black River Falls,",
#     "state": "WI",
#     "zip_code": "54615",
#     "phone": "608-272-3202"
#   },
#   {
#     "region": "northwest",
#     "name": "Fannie’s Supper Club & Motel",
#     "url": "https://wisconsinsupperclubs.com/supper-club/fannies-supper-club-motel/",
#     "website": "https://www.fanniessupperclub.com",
#     "address": "W3741 Hwy 10",
#     "city": "Neillsville,",
#     "state": "WI",
#     "zip_code": "54456",
#     "phone": "715-743-2169"
#   },
#   {
#     "region": "northwest",
#     "name": "Hammond Steak House",
#     "url": "https://wisconsinsupperclubs.com/supper-club/hammond-steak-house/",
#     "website": "http://hammondsteakhouse.com",
#     "address": "1402 North 5th Street",
#     "city": "Superior,",
#     "state": "WI",
#     "zip_code": "54880",
#     "phone": "715-392-3269"
#   },
#   {
#     "region": "northwest",
#     "name": "High View Inn",
#     "url": "https://wisconsinsupperclubs.com/supper-club/high-view-inn/",
#     "website": "https://www.restaurantji.com/wi/medford/high-view-inn-/",
#     "address": "W7766 Perkinstown Avenue",
#     "city": "Medford,",
#     "state": "WI",
#     "zip_code": "54451",
#     "phone": "715-785-7847"
#   },
#   {
#     "region": "northwest",
#     "name": "Hillside Fish House",
#     "url": "https://wisconsinsupperclubs.com/supper-club/hillside-fish-house/",
#     "website": "http://hillsidefishhouse.com/",
#     "address": "W126 Hwy 35",
#     "city": "Fountain City,",
#     "state": "WI",
#     "zip_code": "54629",
#     "phone": "715-687-6141"
#   },
#   {
#     "region": "northwest",
#     "name": "Hilltop Retreat",
#     "url": "https://wisconsinsupperclubs.com/supper-club/hilltop-retreat/",
#     "website": "https://hilltopretreat-cumberland.com",
#     "address": "2896 1 1/2 Street",
#     "city": "Cumberland",
#     "state": "WI",
#     "zip_code": "54829",
#     "phone": "715-822-3230"
#   },
#   {
#     "region": "northwest",
#     "name": "Houligans Steak & Seafood Pub",
#     "url": "https://wisconsinsupperclubs.com/supper-club/houligans-steak-seafood-pub/",
#     "website": "https://houligans.net",
#     "address": "415 South Barstow Street",
#     "city": "Eau Claire,",
#     "state": "WI",
#     "zip_code": "54701",
#     "phone": "715-835-6621"
#   },
#   {
#     "region": "northwest",
#     "name": "Indianhead Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/indianhead-supper-club/",
#     "website": "http://www.indianheadsupperclub.com/",
#     "address": "107 Indianhead Shores Drive",
#     "city": "Balsam Lake,",
#     "state": "WI",
#     "zip_code": "54810",
#     "phone": "715-485-3359"
#   },
#   {
#     "region": "northwest",
#     "name": "Inwood Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/inwood-supper-club/",
#     "website": "https://www.facebook.com/Inwood-Supper-Club-193848163993767/",
#     "address": "N9503 County Road K",
#     "city": "Merrillan,",
#     "state": "WI",
#     "zip_code": "54754",
#     "phone": "715-333-6653"
#   },
#   {
#     "region": "northwest",
#     "name": "Jake’s Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/jakes-supper-club/",
#     "website": "http://jakessupperclub.com/",
#     "address": "E5690 County Road D",
#     "city": "Menomonie,",
#     "state": "WI",
#     "zip_code": "54751",
#     "phone": "715-235-2465"
#   },
#   {
#     "region": "northwest",
#     "name": "John & Heidi’s Happy Daze",
#     "url": "https://wisconsinsupperclubs.com/supper-club/john-heidis-happy-daze/",
#     "website": "https://www.facebook.com/people/John-and-Heidi-s-Happy-Daze/61551507800668/",
#     "address": "W10088 US 8",
#     "city": "Kennan",
#     "state": "WI",
#     "zip_code": "54537",
#     "phone": "715-474-2409"
#   },
#   {
#     "region": "northwest",
#     "name": "JS Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/js-supper-club/",
#     "website": "https://www.restaurantji.com/wi/ladysmith/js-supper-club-and-catering-/",
#     "address": "W9594 Hwy 8",
#     "city": "Ladysmith,",
#     "state": "WI",
#     "zip_code": "54848",
#     "phone": "715-532-7897"
#   },
#   {
#     "region": "northwest",
#     "name": "Kimball Inn",
#     "url": "https://wisconsinsupperclubs.com/supper-club/kimball-inn/",
#     "website": "https://www.facebook.com/KimballInn/",
#     "address": "6622 Hwy 2",
#     "city": "Hurley,",
#     "state": "WI",
#     "zip_code": "54534",
#     "phone": "715-561-4095"
#   },
#   {
#     "region": "northwest",
#     "name": "Kincaid’s Country Inn",
#     "url": "https://wisconsinsupperclubs.com/supper-club/kincaids-country-inn/",
#     "website": "https://kincaidscountryinn.com",
#     "address": "2499 County Road SS",
#     "city": "Rice Lake,",
#     "state": "WI",
#     "zip_code": "54868",
#     "phone": "715-234-4803"
#   },
#   {
#     "region": "northwest",
#     "name": "Kutzee’s Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/kutzees-supper-club/",
#     "website": "https://www.facebook.com/Kutzees/",
#     "address": "34027 County Hwy X",
#     "city": "Stanley,",
#     "state": "WI",
#     "zip_code": "54768",
#     "phone": "715-644-5700"
#   },
#   {
#     "region": "northwest",
#     "name": "Laurel Supper Club, The",
#     "url": "https://wisconsinsupperclubs.com/supper-club/the-laurel-supper-club/",
#     "website": "https://www.restaurantji.com/wi/new-richmond/laurel-supper-club-/",
#     "address": "1905 Hwy 64",
#     "city": "New Richmond,",
#     "state": "WI",
#     "zip_code": "54017",
#     "phone": "715-246-5121"
#   },
#   {
#     "region": "northwest",
#     "name": "Lehman’s Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/lehmans-supper-club/",
#     "website": "http://lehmanssupperclub.net/",
#     "address": "2911 South Main Street",
#     "city": "Rice Lake,",
#     "state": "WI",
#     "zip_code": "54868",
#     "phone": "715-234-9911"
#   },
#   {
#     "region": "northwest",
#     "name": "Monkey’s Roost",
#     "url": "https://wisconsinsupperclubs.com/supper-club/monkeys-roost/",
#     "website": "https://www.restaurantji.com/wi/melrose/monkeys-roost-/",
#     "address": "1011 Hwy 71",
#     "city": "Melrose,",
#     "state": "WI",
#     "zip_code": "54642",
#     "phone": "608-488-5791"
#   },
#   {
#     "region": "northwest",
#     "name": "Northwoods Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/northwoods-supper-club/",
#     "website": "https://www.facebook.com/Northwoods-Supper-Club-113984821956457/",
#     "address": "N14066 Flambeau Avenue",
#     "city": "Fifield,",
#     "state": "WI",
#     "zip_code": "54524",
#     "phone": "715-762-4447"
#   },
#   {
#     "region": "northwest",
#     "name": "Old Abe’s Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/old-abes-supper-club/",
#     "website": "https://facebook.com/OldAbesSupperClub",
#     "address": "17256 155th Avenue",
#     "city": "Jim Falls,",
#     "state": "WI",
#     "zip_code": "54748",
#     "phone": "715-382-4656"
#   },
#   {
#     "region": "northwest",
#     "name": "P&E Steakhouse",
#     "url": "https://wisconsinsupperclubs.com/supper-club/pe-steakhouse/",
#     "website": "http://pesteakhouse.com",
#     "address": "N2319 State Hwy 13",
#     "city": "Medford,",
#     "state": "WI",
#     "zip_code": "54451",
#     "phone": "715-748-2975"
#   },
#   {
#     "region": "northwest",
#     "name": "Pine Ridge",
#     "url": "https://wisconsinsupperclubs.com/supper-club/pine-ridge/",
#     "website": "http://www.pineridgewi.com/",
#     "address": "16618 Sissabagama Road",
#     "city": "Stone Lake,",
#     "state": "WI",
#     "zip_code": "54876",
#     "phone": "715-865-2796"
#   },
#   {
#     "region": "northwest",
#     "name": "Ranch Supper Club, The *†",
#     "url": "https://wisconsinsupperclubs.com/supper-club/the-ranch-supper-club/",
#     "website": "https://ranchsupperclub.com",
#     "address": "10590 North Ranch Road",
#     "city": "Hayward,",
#     "state": "WI",
#     "zip_code": "54843",
#     "phone": "715-634-2090"
#   },
#   {
#     "region": "northwest",
#     "name": "Rolling Oaks Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/rolling-oaks-supper-club/",
#     "website": "https://www.rollingoakssupperclub.com",
#     "address": "450 West Division Avenue",
#     "city": "Barron",
#     "state": "WI",
#     "zip_code": "54812",
#     "phone": "715-537-9300"
#   },
#   {
#     "region": "northwest",
#     "name": "Shady Grove",
#     "url": "https://wisconsinsupperclubs.com/supper-club/shady-grove/",
#     "website": "https://shadygrovewi.com/index.html",
#     "address": "N6240 State Road 65",
#     "city": "Ellsworth,",
#     "state": "WI",
#     "zip_code": "54011",
#     "phone": "715-273-3787"
#   },
#   {
#     "region": "northwest",
#     "name": "Steakhouse & Lodge, The",
#     "url": "https://wisconsinsupperclubs.com/supper-club/the-steakhouse-lodge/",
#     "website": "https://www.steakhouseandlodge.com/restaurant-in-hayward-wi",
#     "address": "15860 T Bone Lane",
#     "city": "Hayward,",
#     "state": "WI",
#     "zip_code": "54843",
#     "phone": "715-934-4411"
#   },
#   {
#     "region": "northwest",
#     "name": "Sullivan’s Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/sullivans-supper-club/",
#     "website": "https://sullivanssupperclub.com",
#     "address": "W25709 Sullivan Road",
#     "city": "Trempealeau,",
#     "state": "WI",
#     "zip_code": "54661",
#     "phone": "608-534-7775"
#   },
#   {
#     "region": "northwest",
#     "name": "Sunset Bay Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/sunset-bay-supper-club/",
#     "website": "https://www.sunsetbaysupperclub.com",
#     "address": "N10575 East Solberg Lake Road",
#     "city": "Phillips,",
#     "state": "WI",
#     "zip_code": "54555",
#     "phone": "715-339-3357"
#   },
#   {
#     "region": "northwest",
#     "name": "Tally Ho Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/tally-ho-supper-club/",
#     "website": "http://tallyhosupperclub.com/",
#     "address": "10432 Hwy 77",
#     "city": "Hayward,",
#     "state": "WI",
#     "zip_code": "54843",
#     "phone": "715-462-3646"
#   },
#   {
#     "region": "northwest",
#     "name": "Trailways Inn Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/trailways-inn-supper-club/",
#     "website": "https://www.facebook.com/people/Trailways-Inn-Restaurant/100063610871472/",
#     "address": "16021 West County Road K",
#     "city": "Hayward,",
#     "state": "WI",
#     "zip_code": "54843",
#     "phone": "715-634-2328"
#   },
#   {
#     "region": "northwest",
#     "name": "Turtle Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/turtle-club/",
#     "website": "https://www.restaurantji.com/wi/medford/turtle-club-/",
#     "address": "W7944 Perkinstown Avenue",
#     "city": "Medford,",
#     "state": "WI",
#     "zip_code": "54451",
#     "phone": "715-748-2975"
#   },
#   {
#     "region": "northwest",
#     "name": "Wason’s Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/wasons-supper-club/",
#     "website": "http://www.wasons.com",
#     "address": "W2182 Hwy 54",
#     "city": "Galesville,",
#     "state": "WI",
#     "zip_code": "54630",
#     "phone": "608-582-2763"
#   },
#   {
#     "region": "northwest",
#     "name": "West Wind Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/west-wind-supper-club/",
#     "website": "https://thewestwind.com",
#     "address": "709 North Main Street",
#     "city": "River Falls,",
#     "state": "WI",
#     "zip_code": "54022",
#     "phone": "715-425-8100"
#   },
#   {
#     "region": "northwest",
#     "name": "Wildcat Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/wildcat-supper-club/",
#     "website": "https://www.facebook.com/Wildcatsupperclub/",
#     "address": "W8270 County Road B",
#     "city": "Neillsville,",
#     "state": "WI",
#     "zip_code": "54456",
#     "phone": "715-743-2762"
#   },
#   {
#     "region": "northwest",
#     "name": "Wissota High Shores Supper Club",
#     "url": "https://wisconsinsupperclubs.com/supper-club/wissota-high-shores-supper-club/",
#     "website": "https://wissotahighshores.com/",
#     "address": "17985 Hwy X",
#     "city": "Chippewa Falls,",
#     "state": "WI",
#     "zip_code": "54729",
#     "phone": "715-215-2981"
#   }
# ]

# %%
# add coordinates lat/lon properties using geocoding api
from googlemaps import Client
from typing import List, Dict
import time

def geocode_locations(locations: List[Dict], api_key: str) -> List[Dict]:
    """
    Geocode a list of location dictionaries using Google Maps API.
    
    Args:
        locations (List[Dict]): List of dictionaries containing location information
        api_key (str): Google Maps API key
    
    Returns:
        List[Dict]: Original location data with added latitude and longitude
    """
    # Initialize Google Maps client
    gmaps = Client(key=api_key)
    
    # Process each location
    for location in locations:
        try:
            # Create full address string
            full_address = f"{location['address']}, {location['city']}, {location['state']} {location['zip_code']}"
            
            # Get geocoding result
            result = gmaps.geocode(full_address)
            
            if result and len(result) > 0:
                # Extract latitude and longitude
                lat = result[0]['geometry']['location']['lat']
                lng = result[0]['geometry']['location']['lng']
                
                # Add coordinates to the location dictionary
                location['latitude'] = lat
                location['longitude'] = lng
                location['geocoding_status'] = 'success'
            else:
                # Handle case where no results were found
                location['latitude'] = None
                location['longitude'] = None
                location['geocoding_status'] = 'no_results'
                
            # Add small delay to respect API rate limits
            time.sleep(0.1)
            
        except Exception as e:
            # Handle any errors
            location['latitude'] = None
            location['longitude'] = None
            location['geocoding_status'] = f'error: {str(e)}'
            
    return locations

# %%
# Your API key from Google Maps
API_KEY = os.getenv('GOOGLE_MAPS_API_KEY')

if not API_KEY:
    raise ValueError("Google Maps API key not found in environment variables")

# 初始化 Google Maps client
gmaps = Client(key=API_KEY)

# Geocode the locations
geocoded_locations = geocode_locations(clubs, API_KEY)  # clubs have 304 objects

# Example of accessing the results
for location in geocoded_locations:
    if location['geocoding_status'] == 'success':
        print(f"Location: {location['name']}")
        print(f"Coordinates: {location['latitude']}, {location['longitude']}\n")
    else:
        print(f"Failed to geocode {location['name']}: {location['geocoding_status']}\n")
# Out:
# 2024-11-02 16:30:53,486 - INFO - API queries_quota: 60
# Location: 5 O’Clock Club
# Coordinates: 43.0726325, -88.2778795
#
# Location: Alpine Retreat
# Coordinates: 43.2389669, -88.2877987
#
# Location: Bass Bay Brewhouse
# Coordinates: 42.8998736, -88.11251
#
# Location: Bayside Supper Club
# Coordinates: 43.4432893, -88.8609065
#
# Location: Blue Heron Supper Club
# Coordinates: 42.8839956, -88.2088031
#
# Location: Brittain House Supper Club
# Coordinates: 43.6224959, -88.7243357
#
# Location: Butler Inn of Pewaukee
# Coordinates: 43.087706, -88.2774033
#
# Location: Cantafio’s Buckhorn Steakhouse
# Coordinates: 43.5139937, -88.8103179
#
# Location: Clifford’s Supper Club
# Coordinates: 42.9395025, -88.0440843
#
# Location: Colony House **
# Coordinates: 42.5062829, -88.1208666
#
# Location: Copper Dock, The *†
# Coordinates: 43.2407209, -88.2709137
#
# Location: Corner House Supper Club
# Coordinates: 42.731913, -87.7800798
#
# Location: Diamond Jim’s Steakhouse *†
# Coordinates: 42.9364464, -88.06108150000001
#
# Location: Duck Inn, The *†
# Coordinates: 42.7161862, -88.7403021
#
# Location: Edgewater Supper Club **
# Coordinates: 42.9701548, -88.8088763
#
# Location: Feil’s Supper Club
# Coordinates: 43.51100659999999, -89.0007773
#
# Location: Fitzgerald’s Genoa Junction **
# Coordinates: 42.49706279999999, -88.33085810000001
#
# Location: Five O’Clock Steakhouse **
# Coordinates: 43.0434029, -87.9434211
#
# Location: Great Outdoors Supper Club †
# Coordinates: 43.5134917, -88.1604741
#
# Location: HobNob *†
# Coordinates: 42.663143, -87.8089901
#
# Location: House of Gerhard
# Coordinates: 42.5660529, -87.8561818
#
# Location: Iron Ridge Inn
# Coordinates: 43.3980863, -88.5319169
#
# Location: Jack Pandl’s Whitefish Bay Inn
# Coordinates: 43.1109808, -87.8938683
#
# Location: Jackson Grill, The
# Coordinates: 43.0125473, -87.96144559999999
#
# Location: Jail House, The
# Coordinates: 43.3514367, -88.08226730000001
#
# Location: Joey Gerard’s Supper Club
# Coordinates: 42.941821, -87.99657599999999
#
# Location: Johnny Manhattan’s
# Coordinates: 43.2366259, -88.222617
#
# Location: Juice’s Ghost Town
# Coordinates: 43.3206284, -87.9156368
#
# Location: Kurt’s Steakhouse
# Coordinates: 43.0590768, -88.4145254
#
# Location: Little Red Inn
# Coordinates: 43.3698718, -88.3331628
#
# Location: Mars Resort
# Coordinates: 42.591683, -88.5022607
#
# Location: Michael’s on the Lake
# Coordinates: 42.6961092, -88.12449769999999
#
# Location: Milwaukee Steakhouse
# Coordinates: 43.0366743, -87.9884091
#
# Location: Moonlight Tavern Supper Club
# Coordinates: 43.3883133, -87.8706224
#
# Location: Nite Cap Inn
# Coordinates: 42.875828, -88.5847697
#
# Location: North Shore Chophouse
# Coordinates: 42.9095965, -88.91980699999999
#
# Location: Olde Cedar Inn, The
# Coordinates: 43.4025884, -88.26359579999999
#
# Location: Pitch’s
# Coordinates: 43.0545417, -87.8983465
#
# Location: Plier’s Full Circle
# Coordinates: 43.4136108, -87.87079489999999
#
# Location: Range Line Inn
# Coordinates: 43.221391, -87.9437197
#
# Location: Red Circle Inn
# Coordinates: 43.0990499, -88.4033082
#
# Location: Relish Supper Club
# Coordinates: 43.2281103, -88.106184
#
# Location: Sandra’s on the Park
# Coordinates: 42.94223969999999, -88.0388761
#
# Location: Schaumburg Dinner Club
# Coordinates: 43.62883919999999, -88.9627379
#
# Location: Shores of Fox Lake, The
# Coordinates: 43.5784619, -88.9269059
#
# Location: Silver Lake Country Inn
# Coordinates: 43.3925202, -88.2133817
#
# Location: Stagecoach Inn **
# Coordinates: 42.9288944, -88.8370509
#
# Location: Steakout, The †
# Coordinates: 42.9307708, -87.99492049999999
#
# Location: Timmer’s Resort
# Coordinates: 43.3765182, -88.25466689999999
#
# Location: Village Supper Club
# Coordinates: 42.61419540000001, -88.5867624
#
# Location: Village Supper Club
# Coordinates: 42.5156489, -87.8228022
#
# Location: Voelker’s Steak House
# Coordinates: 43.45090949999999, -88.8289787
#
# Location: Wayside Inn, The
# Coordinates: 43.00715719999999, -88.7750504
#
# Location: Wilmot Stage Stop
# Coordinates: 42.5129114, -88.18150399999999
#
# Location: Wisco Supper Club, The
# Coordinates: 43.57347439999999, -88.56088760000002
#
# Location: 3 Mile House *†
# Coordinates: 42.5189139, -90.6056252
#
# Location: 615 Club, The **
# Coordinates: 42.4989337, -89.03011690000001
#
# Location: Arthur’s Supper Club **
# Coordinates: 43.1892106, -90.0746235
#
# Location: Badger Crossing
# Coordinates: 43.7440761, -90.7782807
#
# Location: Benedetti’s Club 51 *†
# Coordinates: 42.5607888, -89.0381305
#
# Location: Buckhorn Supper Club *†
# Coordinates: 42.8422803, -88.97645879999999
#
# Location: Butterfly Club, The *†
# Coordinates: 42.540355, -88.93969899999999
#
# Location: Chop’s Kall Inn *†
# Coordinates: 42.5445938, -90.6227645
#
# Location: Cimaroli’s Supper Club *†
# Coordinates: 43.6115739, -89.58740879999999
#
# Location: Club 60
# Coordinates: 43.3413437, -89.1071201
#
# Location: Club Oasis **
# Coordinates: 43.967531, -90.7632725
#
# Location: Cottonwood, The
# Coordinates: 42.999683, -90.656347
#
# Location: Country Heights Supper Club *†
# Coordinates: 42.5464342, -90.6094578
#
# Location: Crossroads Supper Club
# Coordinates: 42.8439188, -90.4478314
#
# Location: Del Bar, The **
# Coordinates: 43.5994024, -89.793145
#
# Location: Delaney’s **
# Coordinates: 43.0580291, -89.4954425
#
# Location: Digger’s Sting
# Coordinates: 43.8134008, -91.2518099
#
# Location: Dorf Haus Supper Club *†
# Coordinates: 43.2492019, -89.67669889999999
#
# Location: Driftless Social
# Coordinates: 43.0089061, -89.7389127
#
# Location: Drugan’s Castle Mound
# Coordinates: 44.0306127, -91.280678
#
# Location: Fish Tales
# Coordinates: 43.3508212, -89.62997589999999
#
# Location: Fitz’s on the Lake
# Coordinates: 43.3591027, -89.577745
#
# Location: Fredrick’s Supper Club †
# Coordinates: 42.7818601, -88.96283609999999
#
# Location: Freighthouse Restaurant
# Coordinates: 43.8158498, -91.25313059999999
#
# Location: Green Acres Supper Club **
# Coordinates: 43.2708225, -89.722067
#
# Location: Green Lantern Restaurant
# Coordinates: 43.0257421, -89.3062782
#
# Location: Hi Point Steakhouse †
# Coordinates: 43.0054808, -89.9742899
#
# Location: Hideaway Acres
# Coordinates: 42.564509, -90.351773
#
# Location: Hilltop, The †
# Coordinates: 43.1182722, -89.6520973
#
# Location: House of Embers
# Coordinates: 43.6008271, -89.79429979999999
#
# Location: Ishnala *†
# Coordinates: 43.5754569, -89.80945460000001
#
# Location: Jones’ Black Angus *†
# Coordinates: 43.023562, -91.11976790000001
#
# Location: Kickapoo Creekside
# Coordinates: 43.4446369, -90.76839679999999
#
# Location: Lake House Inn
# Coordinates: 42.8422533, -89.00459590000001
#
# Location: Louisburg Junction Supper Club
# Coordinates: 42.5782744, -90.556525
#
# Location: Maple Tree Supper Club
# Coordinates: 43.0125071, -89.3038772
#
# Location: Mariner’s
# Coordinates: 43.1489218, -89.4070057
#
# Location: Old Towne Inn **
# Coordinates: 43.6395483, -90.86571359999999
#
# Location: Owl’s Nest
# Coordinates: 43.3957313, -89.39452949999999
#
# Location: Red’s Supper Club
# Coordinates: 42.6673912, -90.3581769
#
# Location: Rex’s Innkeeper
# Coordinates: 43.1943726, -89.46243319999999
#
# Location: Ridge, The
# Coordinates: 43.7855386, -91.0446012
#
# Location: Rocky’s Supper Club *†
# Coordinates: 43.6619009, -91.2187038
#
# Location: Suzy’s Steak & Seafood
# Coordinates: 43.5701043, -89.47689609999999
#
# Location: Toby’s Supper Club
# Coordinates: 43.0440111, -89.3027872
#
# Location: Tornado Club Steak House *†
# Coordinates: 43.072486, -89.3845981
#
# Location: Turn Key Supper Club
# Coordinates: 43.0886583, -89.3647606
#
# Location: Village Bar Supper Club, The **
# Coordinates: 42.5877737, -90.5936485
#
# Location: Village Inn
# Coordinates: 43.8913147, -90.9893136
#
# Location: Westview Inn
# Coordinates: 43.8953054, -91.08170249999999
#
# Location: Woodbine Inn
# Coordinates: 44.0456826, -90.0218993
#
# Location: Zeman’s Old Highway House
# Coordinates: 43.47604399999999, -89.7683931
#
# Location: Alexander’s
# Coordinates: 45.1338033, -87.2106972
#
# Location: Altona Supper Club
# Coordinates: 43.9569936, -88.107692
#
# Location: Anderson’s Supper Club
# Coordinates: 45.3012082, -88.54243040000001
#
# Location: Ballering, The
# Coordinates: 44.4521838, -87.5030607
#
# Location: Bavarian Inn
# Coordinates: 44.9512444, -88.0466624
#
# Location: Billy’s on Main
# Coordinates: 44.5386226, -87.7039312
#
# Location: Black Otter Supper Club
# Coordinates: 44.3304274, -88.6398257
#
# Location: Blanck’s Supper Club †
# Coordinates: 43.8776932, -88.2900222
#
# Location: Boarding House **
# Coordinates: 44.9992121, -88.3716913
#
# Location: Bob & Laura’s Supper Club
# Coordinates: 45.1116822, -88.02346779999999
#
# Location: Brown’s Corner
# Coordinates: 45.0544424, -87.7636294
#
# Location: Butte Des Morts Supper Club
# Coordinates: 44.0997896, -88.6533718
#
# Location: Cattails Supper Club
# Coordinates: 44.2044844, -88.7324304
#
# Location: Cedar Lodge
# Coordinates: 43.9361013, -88.303438
#
# Location: Century Elm Supper Club
# Coordinates: 44.1918188, -88.60439799999999
#
# Location: Chissy’s Pub & Grill
# Coordinates: 43.6818159, -87.93865699999999
#
# Location: Club Chalet **
# Coordinates: 44.6106249, -87.84342559999999
#
# Location: Colonial House Supper Club
# Coordinates: 44.3942382, -88.2773665
#
# Location: Dan and Tim’s Riverside
# Coordinates: 45.2325864, -88.01260130000001
#
# Location: Dick and Joan’s Supper Club
# Coordinates: 44.2651942, -88.4453676
#
# Location: Donny’s Glidden Lodge †
# Coordinates: 44.8967492, -87.2158753
#
# Location: Embers 1871
# Coordinates: 45.056103, -87.770215
#
# Location: English Inn, The
# Coordinates: 45.1326283, -87.21281239999999
#
# Location: Five Pillars Supper Club
# Coordinates: 43.55222, -87.9617585
#
# Location: Geno’s Steakhouse †
# Coordinates: 44.5550203, -88.43528309999999
#
# Location: George’s Steakhouse
# Coordinates: 44.2411748, -88.4194991
#
# Location: Gib’s on the Lake **
# Coordinates: 44.32788480000001, -87.54422439999999
#
# Location: Gobbler’s Knob
# Coordinates: 44.0720413, -88.2993797
#
# Location: Granary Supper Club, The
# Coordinates: 44.1805309, -88.253355
#
# Location: Haase’s Supper Club
# Coordinates: 44.0978584, -88.8749465
#
# Location: Harbor Fish Market & Grille
# Coordinates: 45.0634003, -87.12348539999999
#
# Location: Harborside
# Coordinates: 44.0935395, -87.6566861
#
# Location: Hillcrest Lodge Supper Club
# Coordinates: 45.3274324, -88.5964261
#
# Location: Hotel Seymour Supper Club
# Coordinates: 44.5114226, -88.3299662
#
# Location: Jim and Linda’s Lakeview
# Coordinates: 43.9142926, -88.3327341
#
# Location: Jimmies White House Inn
# Coordinates: 44.1003098, -88.6535112
#
# Location: Koehring’s Grand Central House
# Coordinates: 43.9126726, -88.03787969999999
#
# Location: Krabbe’s Supper Club
# Coordinates: 44.444072, -88.33086899999999
#
# Location: Kropp’s Supper Club *†
# Coordinates: 44.5880134, -88.1591625
#
# Location: Long Drive Supper Club
# Coordinates: 44.5262198, -88.14952620000001
#
# Location: Lox Club *†
# Coordinates: 44.2692219, -88.2974266
#
# Location: Maiden Lake Supper Club *†
# Coordinates: 45.27555539999999, -88.521261
#
# Location: Majerle’s Black River Grill †
# Coordinates: 43.6965781, -87.7064632
#
# Location: Mark’s East Side
# Coordinates: 44.2727294, -88.38276570000001
#
# Location: Marq Supper Club, The
# Coordinates: 44.3798334, -88.1647048
#
# Location: Marty’s Place Supper Club
# Coordinates: 44.2742292, -88.334688
#
# Location: Michiels of Menasha
# Coordinates: 44.2199617, -88.42995619999999
#
# Location: Mill Supper Club, The *†
# Coordinates: 44.8702317, -87.3358889
#
# Location: Millhome Supper Club
# Coordinates: 43.8979655, -87.97560370000001
#
# Location: Moxie’s Supper Club
# Coordinates: 44.55189230000001, -87.6182204
#
# Location: Nightingale Supper Club **
# Coordinates: 44.8499892, -87.35744129999999
#
# Location: Nimrod Inn Supper Club
# Coordinates: 45.4240722, -88.0996274
#
# Location: Off the Wolf Supper Club
# Coordinates: 44.1111495, -88.7139246
#
# Location: Out-O-Town Supper Club
# Coordinates: 44.3167398, -88.2231815
#
# Location: PJ Campbell’s at the Depot
# Coordinates: 43.745603, -87.978736
#
# Location: Prime Steer Supper Club
# Coordinates: 44.2899002, -88.2696102
#
# Location: Red Cabin at Green Acres
# Coordinates: 43.7551141, -88.2913844
#
# Location: Red Ox Seafood & Steak
# Coordinates: 44.2409685, -88.40367409999999
#
# Location: Redwood Inn
# Coordinates: 44.442293, -87.9229106
#
# Location: Rene’s Dining Room
# Coordinates: 45.3067527, -88.1794951
#
# Location: Richards of Dunbar Supper Club
# Coordinates: 45.6500563, -88.1684463
#
# Location: River’s Bend
# Coordinates: 44.5619801, -88.0625132
#
# Location: River’s Edge, The **
# Coordinates: 45.1110664, -87.667932
#
# Location: Rock Falls Supper Club
# Coordinates: 44.6348287, -87.7816814
#
# Location: Roepke’s Supper Club *†
# Coordinates: 43.970034, -88.1713243
#
# Location: Romy’s Nitingale
# Coordinates: 44.4273876, -88.47246969999999
#
# Location: Roxy Supper Club, The
# Coordinates: 44.0218829, -88.53786579999999
#
# Location: Rupp’s Downtown
# Coordinates: 43.7544551, -87.7127636
#
# Location: Rupp’s Supper Club
# Coordinates: 43.9142809, -87.74925859999999
#
# Location: Schmitz Brothers 2 Supper Club
# Coordinates: 44.1387852, -88.16375479999999
#
# Location: Schwarz’s Supper Club *†
# Coordinates: 43.8918839, -88.12177899999999
#
# Location: Sebastian’s Steak House
# Coordinates: 43.75778, -88.44932829999999
#
# Location: Sister Bay Bowl
# Coordinates: 45.1874684, -87.1223691
#
# Location: T&T Steakhouse
# Coordinates: 45.7841118, -88.08343409999999
#
# Location: Theo’s 24
# Coordinates: 43.7796053, -88.4472969
#
# Location: Twin Bridge Supper Club
# Coordinates: 45.3136375, -88.2001921
#
# Location: Union Hotel
# Coordinates: 44.4502393, -88.0601599
#
# Location: Van Abel’s of Hollandtown
# Coordinates: 44.2513787, -88.17260110000001
#
# Location: Weatherwood Supper Club
# Coordinates: 45.1576915, -88.4507038
#
# Location: Wendt’s on the Lake
# Coordinates: 43.89325760000001, -88.4686401
#
# Location: Whitetail Inn
# Coordinates: 45.9212952, -89.5523071
#
# Location: Wildflower Supper Club
# Coordinates: 44.4580879, -87.5035032
#
# Location: Aberdeen Restaurant & Bar
# Coordinates: 46.1013035, -89.82068559999999
#
# Location: Amy’s Roadhouse
# Coordinates: 44.7970981, -88.6920461
#
# Location: Antlers Supper Club *†
# Coordinates: 44.739365, -88.4454574
#
# Location: Asana Suka
# Coordinates: 46.1540559, -89.2050411
#
# Location: Ash’s
# Coordinates: 45.8811127, -88.152339
#
# Location: Bear Trap Inn, The †
# Coordinates: 46.1561938, -89.2494482
#
# Location: Belvedere Supper Club
# Coordinates: 44.718568, -90.10809
#
# Location: Besse’s on Clear Lake
# Coordinates: 45.538261, -89.7329657
#
# Location: Bootleggers Lodge
# Coordinates: 45.5606278, -89.7102884
#
# Location: Branding Iron Supper Club **
# Coordinates: 44.3054274, -89.8096576
#
# Location: Buck-A-Neer Supper Club *†
# Coordinates: 44.7427077, -90.02593999999999
#
# Location: Chanticleer Inn
# Coordinates: 45.9218313, -89.1960416
#
# Location: Chef Rene’s at Eagle River
# Coordinates: 45.9077834, -89.28943149999999
#
# Location: Classic’s Restaurant & Lounge
# Coordinates: 44.8290315, -88.5457059
#
# Location: Clearview Supper Club
# Coordinates: 45.9125359, -89.4645201
#
# Location: Club 22
# Coordinates: 44.7315637, -88.67823
#
# Location: Club 23
# Coordinates: 43.65016079999999, -89.6715739
#
# Location: Cove Supper Club, The
# Coordinates: 43.6510063, -89.6115811
#
# Location: Crystal’s Wood Lake Supper Club
# Coordinates: 43.98184879999999, -89.51304069999999
#
# Location: Dixon’s Torchlite
# Coordinates: 44.7811598, -88.5773524
#
# Location: Dockers on the Corner
# Coordinates: 44.8453139, -88.5012304
#
# Location: Eagle Waters Resort
# Coordinates: 45.9363046, -89.19813339999999
#
# Location: Eddie B’s White Spruce
# Coordinates: 45.9200408, -89.25387959999999
#
# Location: El Capitan Supper Club
# Coordinates: 45.87583069999999, -88.0894867
#
# Location: Fireside Supper Club
# Coordinates: 45.6224479, -89.4674453
#
# Location: Four Seasons Supper Club **
# Coordinates: 45.92053809999999, -89.64717259999999
#
# Location: Guide’s Inn, The
# Coordinates: 46.10871359999999, -89.64264159999999
#
# Location: Hidden Valley Supper Club
# Coordinates: 44.71998259999999, -88.8895254
#
# Location: JJ’s on Main
# Coordinates: 44.8631939, -88.985321
#
# Location: Jung’s Nutshell Supper Club
# Coordinates: 45.0513547, -89.0216784
#
# Location: Kassidy’s Studio Lounge
# Coordinates: 44.7822064, -88.60899169999999
#
# Location: Kathy & Cal’s Club 64
# Coordinates: 45.1769208, -89.7325893
#
# Location: Lake Aire Supper Club
# Coordinates: 44.335482, -89.8155159
#
# Location: Lanny’s Fireside Supper Club
# Coordinates: 46.102731, -89.22791000000001
#
# Location: Lawson’s Triple O Supper Club
# Coordinates: 44.5577583, -88.87970729999999
#
# Location: Marty’s Place North
# Coordinates: 45.97812450000001, -89.6999828
#
# Location: Mathew’s Supper Club
# Coordinates: 44.6210664, -88.7722313
#
# Location: McGregor’s Blink Bonnie
# Coordinates: 45.920225, -89.54941339999999
#
# Location: Mecan River Lodge
# Coordinates: 43.83197149999999, -89.19892999999999
#
# Location: Meyer’s Clint Mar Supper Club
# Coordinates: 44.6663922, -88.85275879999999
#
# Location: Michele’s Supper Club
# Coordinates: 44.5304637, -89.5743715
#
# Location: MJ’s Supper Club
# Coordinates: 44.3530712, -88.6089782
#
# Location: Moose Inn, The
# Coordinates: 44.0554176, -89.2260793
#
# Location: Northfork Fin & Filet
# Coordinates: 45.92131759999999, -89.6949463
#
# Location: Norton’s of Green Lake
# Coordinates: 43.84429129999999, -88.96419069999999
#
# Location: Norwood Pines Supper Club *†
# Coordinates: 45.8800955, -89.74711719999999
#
# Location: Palms Supper Club
# Coordinates: 44.8870325, -89.6403027
#
# Location: Pine Tree Supper Club
# Coordinates: 45.4707604, -89.7312572
#
# Location: Pine Tree Supper Club **
# Coordinates: 44.4095875, -88.8186721
#
# Location: Pinewood Supper Club *†
# Coordinates: 44.8134402, -89.70981049999999
#
# Location: Pub ‘N’ Prime
# Coordinates: 45.9127594, -89.4884975
#
# Location: Richard’s Restaurant & Bar
# Coordinates: 45.0204888, -89.67684369999999
#
# Location: Savory Steakhouse
# Coordinates: 44.3563014, -89.7250543
#
# Location: Silver Birch Supper Club **
# Coordinates: 45.52185739999999, -89.72971290000001
#
# Location: Silvercryst Supper Club *†
# Coordinates: 44.058662, -89.2339063
#
# Location: Simpson’s in Waupaca
# Coordinates: 44.3562804, -89.08526830000001
#
# Location: Sky Club *†
# Coordinates: 44.4648517, -89.5444122
#
# Location: Smokey’s
# Coordinates: 46.1563102, -89.8759706
#
# Location: Swartzendruber’s Supper Club
# Coordinates: 45.1247209, -89.1657465
#
# Location: Three Coins at Holiday Acres
# Coordinates: 45.6310961, -89.3239957
#
# Location: Twilight Supper Club
# Coordinates: 46.1274056, -89.2056076
#
# Location: Two Lakes **
# Coordinates: 44.2541286, -89.4474698
#
# Location: Wally’s South 17 Supper Club
# Coordinates: 45.6206705, -89.4377349
#
# Location: Washington Inn Supper Club *†
# Coordinates: 44.809889, -88.4515172
#
# Location: Waters Supper Club, The
# Coordinates: 44.3912956, -88.748847
#
# Location: White Stag Inn *†
# Coordinates: 45.8115239, -89.32039119999999
#
# Location: Whitetail Inn
# Coordinates: 45.9212952, -89.5523071
#
# Location: William’s Pine Gables
# Coordinates: 45.91376700000001, -89.27071099999999
#
# Location: Willow Haven Bar & Grill
# Coordinates: 45.702486, -89.84900640000001
#
# Location: Wolff’s River Inn †
# Coordinates: 45.4410214, -89.0809128
#
# Location: 5 O’Clock Club
# Coordinates: 45.58714, -92.0119538
#
# Location: Beedles Bar & Restaurant
# Coordinates: 44.07036189999999, -91.45044539999999
#
# Location: Buckhorn Bar, The
# Coordinates: 45.66840089999999, -91.2383443
#
# Location: Buskey Bay Resort
# Coordinates: 46.5235982, -91.38409730000001
#
# Location: Castle Hill Supper Club
# Coordinates: 44.41672190000001, -90.83343119999999
#
# Location: Cousin’s Hide-A-Way
# Coordinates: 45.6088426, -91.77489299999999
#
# Location: Dalles House, The
# Coordinates: 45.400462, -92.6362456
#
# Location: Ding-A-Ling Supper Club
# Coordinates: 46.131804, -90.0130127
#
# Location: Dreamland Supper Club
# Coordinates: 46.6054667, -91.9468028
#
# Location: Eddie’s
# Coordinates: 46.6739608, -92.0090292
#
# Location: Evergreens Supper Club
# Coordinates: 44.1577969, -90.71350509999999
#
# Location: Fannie’s Supper Club & Motel
# Coordinates: 44.5524509, -90.4983829
#
# Location: Hammond Steak House
# Coordinates: 46.7323339, -92.098315
#
# Location: High View Inn
# Coordinates: 45.19005850000001, -90.4416806
#
# Location: Hillside Fish House
# Coordinates: 44.07121069999999, -91.5572078
#
# Location: Hilltop Retreat
# Coordinates: 45.624365, -92.126978
#
# Location: Houligans Steak & Seafood Pub
# Coordinates: 44.8097184, -91.4980611
#
# Location: Indianhead Supper Club
# Coordinates: 45.4519136, -92.4475537
#
# Location: Inwood Supper Club
# Coordinates: 44.4147018, -90.7311934
#
# Location: Jake’s Supper Club
# Coordinates: 44.9688058, -91.8752007
#
# Location: John & Heidi’s Happy Daze
# Coordinates: 45.5375771, -90.5761522
#
# Location: JS Supper Club
# Coordinates: 45.4630231, -91.10403579999999
#
# Location: Kimball Inn
# Coordinates: 46.491309, -90.2618711
#
# Location: Kincaid’s Country Inn
# Coordinates: 45.4299547, -91.50997009999999
#
# Location: Kutzee’s Supper Club
# Coordinates: 44.9440529, -90.9833065
#
# Location: Laurel Supper Club, The
# Coordinates: 45.1366801, -92.4254283
#
# Location: Lehman’s Supper Club
# Coordinates: 45.47070129999999, -91.7346963
#
# Location: Monkey’s Roost
# Coordinates: 44.09967630000001, -90.9731407
#
# Location: Northwoods Supper Club
# Coordinates: 45.8800407, -90.42056819999999
#
# Location: Old Abe’s Supper Club
# Coordinates: 45.0682013, -91.32296699999999
#
# Location: P&E Steakhouse
# Coordinates: 45.1167869, -90.33086109999999
#
# Location: Pine Ridge
# Coordinates: 45.8035218, -91.5261762
#
# Location: Ranch Supper Club, The *†
# Coordinates: 46.01609, -91.4667022
#
# Location: Rolling Oaks Supper Club
# Coordinates: 45.4007745, -91.86547809999999
#
# Location: Shady Grove
# Coordinates: 44.7656956, -92.48670659999999
#
# Location: Steakhouse & Lodge, The
# Coordinates: 46.0023065, -91.4861988
#
# Location: Sullivan’s Supper Club
# Coordinates: 44.0115682, -91.46238199999999
#
# Location: Sunset Bay Supper Club
# Coordinates: 45.7573602, -90.3612309
#
# Location: Tally Ho Supper Club
# Coordinates: 46.0130065, -91.4846208
#
# Location: Trailways Inn Supper Club
# Coordinates: 45.9140835, -91.4968162
#
# Location: Turtle Club
# Coordinates: 45.1915346, -90.45072789999999
#
# Location: Wason’s Supper Club
# Coordinates: 44.0769114, -91.3566139
#
# Location: West Wind Supper Club
# Coordinates: 44.868471, -92.6223083
#
# Location: Wildcat Supper Club
# Coordinates: 44.5733283, -90.72932089999999
#
# Location: Wissota High Shores Supper Club
# Coordinates: 43.9456524, -86.039215

# %%
for i, club in enumerate(clubs):
    if club['latitude'] is None or club['longitude'] is None:
        print(i,club)

# %%
# Convert list of dictionaries to DataFrame
clubs_geocoded_df = pd.DataFrame(clubs)
clubs_geocoded_df.columns
# Out:
# Index(['region', 'name', 'url', 'website', 'address', 'city', 'state',
#        'zip_code', 'phone', 'latitude', 'longitude', 'geocoding_status'],
#       dtype='object')

# %%
# add id to each row
clubs_geocoded_df['id'] = clubs_geocoded_df.index
clubs_geocoded_df
# Out:
#         region                             name  \
# 0    southeast                   5 O’Clock Club
# 1    southeast                   Alpine Retreat
# 2    southeast               Bass Bay Brewhouse
# 3    southeast              Bayside Supper Club
# 4    southeast           Blue Heron Supper Club
# ..         ...                              ...
# 299  northwest                      Turtle Club
# 300  northwest              Wason’s Supper Club
# 301  northwest            West Wind Supper Club
# 302  northwest              Wildcat Supper Club
# 303  northwest  Wissota High Shores Supper Club
#
#                                                    url  \
# 0    https://wisconsinsupperclubs.com/supper-club/5...
# 1    https://wisconsinsupperclubs.com/supper-club/a...
# 2    https://wisconsinsupperclubs.com/supper-club/b...
# 3    https://wisconsinsupperclubs.com/supper-club/b...
# 4    https://wisconsinsupperclubs.com/supper-club/b...
# ..                                                 ...
# 299  https://wisconsinsupperclubs.com/supper-club/t...
# 300  https://wisconsinsupperclubs.com/supper-club/w...
# 301  https://wisconsinsupperclubs.com/supper-club/w...
# 302  https://wisconsinsupperclubs.com/supper-club/w...
# 303  https://wisconsinsupperclubs.com/supper-club/w...
#
#                                                website  \
# 0                   https://the5oclockclubpewaukee.com
# 1                       https://www.alpineretreat.net/
# 2                     https://www.bassbaybrewhouse.com
# 3    https://www.restaurantji.com/wi/beaver-dam/bay...
# 4     https://www.facebook.com/theblueheronsupperclub/
# ..                                                 ...
# 299  https://www.restaurantji.com/wi/medford/turtle...
# 300                              http://www.wasons.com
# 301                            https://thewestwind.com
# 302        https://www.facebook.com/Wildcatsupperclub/
# 303                     https://wissotahighshores.com/
#
#                        address             city state zip_code         phone  \
# 0    N28 W26658 Peterson Drive         Pewaukee    WI    53072  262-691-9960
# 1        1380 Friess Lake Road        Hubertus,    WI    53033  262-628-3995
# 2     S79 W15851 Aud Mar Drive         Muskego,    WI    53150  414-377-9449
# 3          W9231 County Road G      Beaver Dam,    WI    53916  920-887-0505
# 4           W229 S8300 Hwy 164        Big Bend,    WI    53103  262-662-9985
# ..                         ...              ...   ...      ...           ...
# 299   W7944 Perkinstown Avenue         Medford,    WI    54451  715-748-2975
# 300               W2182 Hwy 54      Galesville,    WI    54630  608-582-2763
# 301      709 North Main Street     River Falls,    WI    54022  715-425-8100
# 302        W8270 County Road B     Neillsville,    WI    54456  715-743-2762
# 303                17985 Hwy X  Chippewa Falls,    WI    54729  715-215-2981
#
#       latitude  longitude geocoding_status   id
# 0    43.072632 -88.277879          success    0
# 1    43.238967 -88.287799          success    1
# 2    42.899874 -88.112510          success    2
# 3    43.443289 -88.860906          success    3
# 4    42.883996 -88.208803          success    4
# ..         ...        ...              ...  ...
# 299  45.191535 -90.450728          success  299
# 300  44.076911 -91.356614          success  300
# 301  44.868471 -92.622308          success  301
# 302  44.573328 -90.729321          success  302
# 303  43.945652 -86.039215          success  303
#
# [304 rows x 13 columns]

# %%
def df_to_csv(
    df: pd.DataFrame,
    filename: str = None,
    output_dir: str = "output"
) -> str:
    """
    Export DataFrame to CSV file.
    
    Args:
        df: DataFrame to export
        filename: Name of output file (without .csv extension)
        output_dir: Directory to save the file
    
    Returns:
        str: Path to saved CSV file
    """
    try:
        # Create output directory if it doesn't exist
        Path(output_dir).mkdir(parents=True, exist_ok=True)
        
        # Generate filename if not provided
        if filename is None:
            filename = "data_export"
        
        full_filename = f"{filename}.csv"
        file_path = os.path.join(output_dir, full_filename)
        
        # Export to CSV
        df.to_csv(
            file_path,
            encoding='utf-8',
            index=False
        )
        
        print(f"Successfully exported to: {file_path}")
        print(f"Rows: {len(df)}, Columns: {len(df.columns)}")
        
        return file_path
        
    except FileNotFoundError as e:
        print(f"Directory error: {str(e)}")
    except PermissionError as e:
        print(f"Permission error: {str(e)}")
    except Exception as e:
        print(f"Unexpected error: {str(e)}")
    return None

# %%
df_to_csv(clubs_geocoded_df, filename="wi_supper_clubs_2023", output_dir="data/csv")
# Out:
# Successfully exported to: data/csv/wi_supper_clubs_2023.csv
# Rows: 304, Columns: 13
# 'data/csv/wi_supper_clubs_2023.csv'
